# %% [markdown]
# # Convert from TEI to TF to WATM
#
# First we convert the corpus TEI to TF and then the TF to WATM.
#
# This notebook is bare, no explanations, no illustrations, no checks.
# For more documentation, try any of the following variants:

# %% [markdown]
# # Step by step
#
# Below you can inspect all the steps of the conversion:

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use
from tf.core.files import fileCopy, dirContents, expanduser as ex
from tff.convert.tei import TEI
from tff.convert.addnlp import NLPipeline
from tff.convert.watm import WATM
from tff.convert.iiif import IIIF
from tff.convert.scans import Scans
from tf.advanced.helpers import dm

# %% [markdown]
# ## Step 0: Scan ingest

# %% [markdown]
# To convert a directory with `.jpf` files to `.jpg` files do
#
# ```
# cd directory
# mogrify -format jpg *.jpf
# ```

# %%
SC = Scans(verbose=1, force=False)
# Out:
# Working in repository HuygensING/israels in back-end github
# Source dir = ~/github/HuygensING/israels
# imageprep settings read from ~/github/HuygensING/israels/config/scans.yml

# %%
SC.process(force=False)
# Out:
# Initialized ~/github/HuygensING/israels/scanInfo
# Initialized ~/github/HuygensING/israels/thumb
# illustrations:
# 	Already present: thumbnails (illustrations)
# 	Already present: sizes file thumbnails (illustrations)
# 		Get sizes of 73 originals (illustrations)
# 			100% done
# 	Copied sizes_illustrations file to scanInfo
# 		Get colorspaces of 73 originals (illustrations)
# 			100% done
# 		Get colorspaces of 73 originals (illustrations)
# 			100% done
# 	originals: 73
# 	thumbnails: 0
# logo:
# pages:
# 	Already present: thumbnails (pages)
# 	Already present: sizes file thumbnails (pages)
# 		Get sizes of 264 originals (pages)
# 			 38% done
# 			 76% done
# 			100% done
# 	Copied sizes_pages file to scanInfo
# 		Get colorspaces of 264 originals (pages)
# 			 38% done
# 			 76% done
# 			100% done
# 		Get colorspaces of 264 originals (pages)
# 			 38% done
# 			 76% done
# 			100% done
# 	originals: 263
# 	thumbnails: 0

# %%
# SC.process(force=True)

# %% [markdown]
# Copy scan info files to the `israels-settings` repo, to directory `scans`

# %%
scanDir = SC.scanDir
destDir = ex("~/gitlab.huc.knaw.nl/eDITem/israels-settings/scans")

for file in dirContents(scanDir)[0]:
    fileCopy(f"{scanDir}/{file}", f"{destDir}/{file}")

# %% [markdown]
# You might also want to do
#
# ### push the changes in israels-settings
#
# ```
# cd ~/gitlab.huc.knaw.nl/eDITem/israels-settings
# git add --all .
# git commit -m "updated image info"
# git push
# ```
#
# ### sync scans to surfdrive
#
# ```
# k
# kset iiif-prod
# app scans ~/github/HuygensING israels up
# ```
#
# follow the prompt instruction to proceed.
#
# ### sync scans to iiif-prod server (production)
#
# Assuming the `kset iiif-prod` is still in force:
#
# ```
# app scans ~/github/HuygensING israels iiif
# ```
#
# After this, you need to empty the server cache:
#
# ```
# ksh
# cd /var/cache/cantaloupe
# rm -rf info image
# ```
#
# ### sync scans to iiif-dev server (development for preview)
#
# ```
# k
# kset iiif-dev
# app scans ~/github/HuygensING israels iiif
# ```
#
# After this, you need to empty the server cache:
#
# ```
# ksh
# cd /var/cache/cantaloupe
# rm -rf info image
# ```
#
# ### run the preview workflow again
#
# SSH into the peen preview machine, the command I have configured (Dirk) is
#
# ```
# ssh peenpreview
# ```
#
# Go to the peen directory by running an `app` command:
#
# ```
# app version
# ```
#
# (Check whether it reports that you are working in preview setting).
#
# Then start a shell in the editem container:
#
# ```
# app sh
# ```
#
# In that shell (you are already in the /app directory), run
#
# ```
# ./workflow.sh israels
# ```
#
# After you see the final OK message:
#
# ```
# exit
# ```
#
# ### run the workflow on the pub machine again
#
# This works exactly the same, but in another VM, which will tell you that you are in publication setting:
#
# ```
# ssh peenpub
# ```
#
# ```
# app version
# app sh
# ./workflow.sh israels
# exit
# ```

# %% [markdown]
# # Step 1: Check

# %%
Tei = TEI(verbose=-1, tei="2025-07-09", tf="0.3.0")

# %%
Tei.task(check=True, verbose=1, validate=True, carryon=True)
# Out:
# TEI to TF checking: ~/github/HuygensING/israels/tei/2025-07-09 => ~/github/HuygensING/israels/report/2025-07-09
# Processing instructions are treated
# XML validation will be performed
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/israels/schema/editem-about.xsd
# 	round   1:  52 changes
# 118 identical override(s)
#   0 changing override(s)
# INFO: Needs editem.xsd (exists)
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/israels/schema/editem-letter.xsd
# Warning: tei:tei_model.divBottom.kind is not defined.
# Warning: tei:tei_model.divBottom.kind is not defined.
# 	round   1:  71 changes
# Warning: tei:tei_model.divBottom.kind is not defined.
# Warning: tei:tei_model.divBottom.kind is not defined.
# 172 identical override(s)
#   2 changing override(s)
# 	artwork complex pure (added)
# 	eventName complex mixed (added)
# INFO: Needs editem.xsd (exists)
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/israels/schema/editem-artworklist.xsd
# 	round   1:  21 changes
# 	round   2:   2 changes
#  29 identical override(s)
#   3 changing override(s)
# 	artwork complex pure (added)
# 	bibl mixed ==> pure
# 	catRef pure ==> mixed
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/israels/schema/editem-biolist.xsd
# 	round   1:  34 changes
# 	round   2:   4 changes
#  38 identical override(s)
#   0 changing override(s)
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/israels/schema/editem-bibliolist.xsd
# 	round   1:  16 changes
#  26 identical override(s)
#   0 changing override(s)
# Section model I
# 	Start folder about
# 	Start folder letters
# 	Start folder apparatus
# 4 editem-about file(s) ...
# 	Validating ...
# 	Making inventory ...
# 103 editem-letter file(s) ...
# 	Validating ...
# 	Making inventory ...
# 1 editem-artworklist file(s) ...
# 	Validating ...
# 	Making inventory ...
# 2 editem-bibliolist file(s) ...
# 	Validating ...
# 	Making inventory ...
# 1 editem-biolist file(s) ...
# 	Validating ...
# 	Making inventory ...
#
# 586 tag(s) type info written to ~/github/HuygensING/israels/report/2025-07-09/types.txt
# Validation OK
# 0 pagebreaks without facs attribute.
# 516 pagebreaks encountered.
# 258 distinct scans referred to by pagebreaks.
# 217 surfaces declared
# 85 zones declared
# 302 scans declared and mapped.
# 3 undeclared scans
# 46 unused surfaces
# 1 unused zone
# 0 processing instructions encountered.
# 72 tags of which 0 with multiple namespaces written to ~/github/HuygensING/israels/report/2025-07-09/namespaces.txt
# 365 info line(s) written to ~/github/HuygensING/israels/report/2025-07-09/elements.txt
# Refs written to ~/github/HuygensING/israels/report/2025-07-09/refs.txt
# 	resolvable:  664 in  664
# 	dangling:    299 in 2061
# 	ALL:         963 in 2725
# Ids written to ~/github/HuygensING/israels/report/2025-07-09/ids.txt
# 	referenced:  664 by  664
# 	non-unique:    0
# 	unused:     3440
# 	ALL:        4104 in 4104
# lb-parent info written to ~/github/HuygensING/israels/report/2025-07-09/lb-parents.txt
# True

# %% [markdown]
# # Step 2: Convert

# %%
Tei.good = True

# %%
Tei.task(convert=True, verbose=0)
# Out:
# Page model II with page nodes for pages started by pb elements without keeping the pb elements
# Section model I
# Processing instructions are treated
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/israels/schema/editem-about.xsd
# 	round   1:  52 changes
# 118 identical override(s)
#   0 changing override(s)
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/israels/schema/editem-letter.xsd
# Warning: tei:tei_model.divBottom.kind is not defined.
# Warning: tei:tei_model.divBottom.kind is not defined.
# 	round   1:  71 changes
# Warning: tei:tei_model.divBottom.kind is not defined.
# Warning: tei:tei_model.divBottom.kind is not defined.
# 172 identical override(s)
#   2 changing override(s)
# 	artwork complex pure (added)
# 	eventName complex mixed (added)
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/israels/schema/editem-artworklist.xsd
# 	round   1:  21 changes
# 	round   2:   2 changes
#  29 identical override(s)
#   3 changing override(s)
# 	artwork complex pure (added)
# 	bibl mixed ==> pure
# 	catRef pure ==> mixed
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/israels/schema/editem-biolist.xsd
# 	round   1:  34 changes
# 	round   2:   4 changes
#  38 identical override(s)
#   0 changing override(s)
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/israels/schema/editem-bibliolist.xsd
# 	round   1:  16 changes
#  26 identical override(s)
#   0 changing override(s)
#   0.00s Importing data from walking through the source ...
#    |     0.00s Preparing metadata...
#    |     0.00s OK
#    |     0.00s Following director...
# 	Start folder about:
# 		   1 editem-about              about        Inleiding_introduction.xml
# targetNode=('head', 3) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 2), 'chunk': ('chunk', 6), 'figure': ('figure', 1), 'head': ('head', 3)}
# targetNode=('head', 4) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 2), 'chunk': ('chunk', 8), 'figure': ('figure', 2), 'head': ('head', 4)}
# targetNode=('head', 5) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 2), 'chunk': ('chunk', 9), 'figure': ('figure', 3), 'head': ('head', 5)}
# targetNode=('head', 6) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 2), 'chunk': ('chunk', 15), 'figure': ('figure', 4), 'head': ('head', 6)}
# targetNode=('head', 7) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 2), 'chunk': ('chunk', 17), 'figure': ('figure', 5), 'head': ('head', 7)}
# targetNode=('head', 8) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 2), 'chunk': ('chunk', 18), 'figure': ('figure', 6), 'head': ('head', 8)}
# targetNode=('head', 9) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 2), 'chunk': ('chunk', 19), 'figure': ('figure', 7), 'head': ('head', 9)}
# targetNode=('head', 10) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 2), 'chunk': ('chunk', 21), 'figure': ('figure', 8), 'head': ('head', 10)}
# targetNode=('head', 11) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 2), 'chunk': ('chunk', 25), 'figure': ('figure', 9), 'head': ('head', 11)}
# targetNode=('head', 13) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 3), 'chunk': ('chunk', 28), 'figure': ('figure', 10), 'head': ('head', 13)}
# targetNode=('head', 14) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 3), 'chunk': ('chunk', 32), 'figure': ('figure', 11), 'head': ('head', 14)}
# targetNode=('head', 15) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 3), 'chunk': ('chunk', 40), 'figure': ('figure', 12), 'head': ('head', 15)}
# targetNode=('head', 16) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 3), 'chunk': ('chunk', 41), 'figure': ('figure', 13), 'head': ('head', 16)}
# targetNode=('head', 17) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 3), 'chunk': ('chunk', 42), 'figure': ('figure', 14), 'head': ('head', 17)}
# targetNode=('head', 18) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 3), 'chunk': ('chunk', 44), 'figure': ('figure', 15), 'head': ('head', 18)}
# targetNode=('head', 19) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 3), 'chunk': ('chunk', 46), 'figure': ('figure', 16), 'head': ('head', 19)}
# targetNode=('head', 20) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 3), 'chunk': ('chunk', 47), 'figure': ('figure', 17), 'head': ('head', 20)}
# targetNode=('head', 22) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 4), 'chunk': ('chunk', 51), 'figure': ('figure', 18), 'head': ('head', 22)}
# targetNode=('head', 24) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 5), 'chunk': ('chunk', 54), 'figure': ('figure', 19), 'head': ('head', 24)}
# targetNode=('head', 25) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 5), 'chunk': ('chunk', 56), 'figure': ('figure', 20), 'head': ('head', 25)}
# targetNode=('head', 27) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 6), 'chunk': ('chunk', 58), 'figure': ('figure', 21), 'head': ('head', 27)}
# targetNode=('head', 29) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 7), 'chunk': ('chunk', 61), 'figure': ('figure', 22), 'head': ('head', 29)}
# targetNode=('head', 32) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 9), 'chunk': ('chunk', 73), 'figure': ('figure', 23), 'head': ('head', 32)}
# targetNode=('head', 33) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 9), 'chunk': ('chunk', 75), 'figure': ('figure', 24), 'head': ('head', 33)}
# targetNode=('head', 34) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 9), 'chunk': ('chunk', 76), 'figure': ('figure', 25), 'head': ('head', 34)}
# targetNode=('head', 36) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 10), 'chunk': ('chunk', 80), 'figure': ('figure', 26), 'head': ('head', 36)}
# targetNode=('head', 37) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 10), 'chunk': ('chunk', 81), 'figure': ('figure', 27), 'head': ('head', 37)}
# targetNode=('head', 39) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 11), 'chunk': ('chunk', 84), 'figure': ('figure', 28), 'head': ('head', 39)}
# targetNode=('head', 41) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 12), 'chunk': ('chunk', 87), 'figure': ('figure', 29), 'head': ('head', 41)}
# targetNode=('head', 44) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 14), 'chunk': ('chunk', 92), 'figure': ('figure', 30), 'head': ('head', 44)}
# targetNode=('head', 46) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 15), 'chunk': ('chunk', 94), 'figure': ('figure', 31), 'head': ('head', 46)}
# targetNode=('head', 48) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 16), 'chunk': ('chunk', 97), 'figure': ('figure', 32), 'head': ('head', 48)}
# targetNode=('head', 49) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 16), 'chunk': ('chunk', 99), 'figure': ('figure', 33), 'head': ('head', 49)}
# targetNode=('head', 50) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 16), 'chunk': ('chunk', 100), 'figure': ('figure', 34), 'head': ('head', 50)}
# targetNode=('head', 51) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 16), 'chunk': ('chunk', 101), 'figure': ('figure', 35), 'head': ('head', 51)}
# targetNode=('head', 52) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 16), 'chunk': ('chunk', 102), 'figure': ('figure', 36), 'head': ('head', 52)}
# targetNode=('head', 54) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 17), 'chunk': ('chunk', 104), 'figure': ('figure', 37), 'head': ('head', 54)}
# targetNode=('head', 56) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 18), 'chunk': ('chunk', 106), 'figure': ('figure', 38), 'head': ('head', 56)}
# targetNode=('head', 58) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 19), 'chunk': ('chunk', 109), 'figure': ('figure', 39), 'head': ('head', 58)}
# targetNode=('head', 60) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 20), 'chunk': ('chunk', 111), 'figure': ('figure', 40), 'head': ('head', 60)}
# targetNode=('head', 62) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 21), 'chunk': ('chunk', 114), 'figure': ('figure', 41), 'head': ('head', 62)}
# targetNode=('head', 64) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 22), 'chunk': ('chunk', 117), 'figure': ('figure', 42), 'head': ('head', 64)}
# targetNode=('head', 66) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 23), 'chunk': ('chunk', 122), 'figure': ('figure', 43), 'head': ('head', 66)}
# targetNode=('head', 68) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 24), 'chunk': ('chunk', 125), 'figure': ('figure', 44), 'head': ('head', 68)}
# targetNode=('head', 70) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 25), 'chunk': ('chunk', 128), 'figure': ('figure', 45), 'head': ('head', 70)}
# targetNode=('head', 72) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 26), 'chunk': ('chunk', 131), 'figure': ('figure', 46), 'head': ('head', 72)}
# targetNode=('head', 74) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 27), 'chunk': ('chunk', 134), 'figure': ('figure', 47), 'head': ('head', 74)}
# targetNode=('head', 76) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 28), 'chunk': ('chunk', 137), 'figure': ('figure', 48), 'head': ('head', 76)}
# targetNode=('head', 78) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 29), 'chunk': ('chunk', 140), 'figure': ('figure', 49), 'head': ('head', 78)}
# targetNode=('head', 79) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 29), 'chunk': ('chunk', 142), 'figure': ('figure', 50), 'head': ('head', 79)}
# targetNode=('head', 80) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 29), 'chunk': ('chunk', 143), 'figure': ('figure', 51), 'head': ('head', 80)}
# targetNode=('head', 81) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 29), 'chunk': ('chunk', 144), 'figure': ('figure', 52), 'head': ('head', 81)}
# targetNode=('head', 83) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 30), 'chunk': ('chunk', 146), 'figure': ('figure', 53), 'head': ('head', 83)}
# targetNode=('head', 87) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 33), 'chunk': ('chunk', 157), 'figure': ('figure', 54), 'head': ('head', 87)}
# targetNode=('head', 88) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 33), 'chunk': ('chunk', 159), 'figure': ('figure', 55), 'head': ('head', 88)}
# targetNode=('head', 89) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 33), 'chunk': ('chunk', 160), 'figure': ('figure', 56), 'head': ('head', 89)}
# targetNode=('head', 90) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 33), 'chunk': ('chunk', 166), 'figure': ('figure', 57), 'head': ('head', 90)}
# targetNode=('head', 91) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 33), 'chunk': ('chunk', 168), 'figure': ('figure', 58), 'head': ('head', 91)}
# targetNode=('head', 92) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 33), 'chunk': ('chunk', 169), 'figure': ('figure', 59), 'head': ('head', 92)}
# targetNode=('head', 93) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 33), 'chunk': ('chunk', 170), 'figure': ('figure', 60), 'head': ('head', 93)}
# targetNode=('head', 94) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 33), 'chunk': ('chunk', 172), 'figure': ('figure', 61), 'head': ('head', 94)}
# targetNode=('head', 95) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 33), 'chunk': ('chunk', 176), 'figure': ('figure', 62), 'head': ('head', 95)}
# targetNode=('head', 97) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 34), 'chunk': ('chunk', 179), 'figure': ('figure', 63), 'head': ('head', 97)}
# targetNode=('head', 98) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 34), 'chunk': ('chunk', 183), 'figure': ('figure', 64), 'head': ('head', 98)}
# targetNode=('head', 99) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 34), 'chunk': ('chunk', 191), 'figure': ('figure', 65), 'head': ('head', 99)}
# targetNode=('head', 100) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 34), 'chunk': ('chunk', 192), 'figure': ('figure', 66), 'head': ('head', 100)}
# targetNode=('head', 101) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 34), 'chunk': ('chunk', 193), 'figure': ('figure', 67), 'head': ('head', 101)}
# targetNode=('head', 102) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 34), 'chunk': ('chunk', 195), 'figure': ('figure', 68), 'head': ('head', 102)}
# targetNode=('head', 103) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 34), 'chunk': ('chunk', 197), 'figure': ('figure', 69), 'head': ('head', 103)}
# targetNode=('head', 104) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 34), 'chunk': ('chunk', 198), 'figure': ('figure', 70), 'head': ('head', 104)}
# targetNode=('head', 106) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 35), 'chunk': ('chunk', 202), 'figure': ('figure', 71), 'head': ('head', 106)}
# targetNode=('head', 108) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 36), 'chunk': ('chunk', 205), 'figure': ('figure', 72), 'head': ('head', 108)}
# targetNode=('head', 109) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 36), 'chunk': ('chunk', 207), 'figure': ('figure', 73), 'head': ('head', 109)}
# targetNode=('head', 111) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 37), 'chunk': ('chunk', 209), 'figure': ('figure', 74), 'head': ('head', 111)}
# targetNode=('head', 113) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 38), 'chunk': ('chunk', 212), 'figure': ('figure', 75), 'head': ('head', 113)}
# targetNode=('head', 116) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 40), 'chunk': ('chunk', 224), 'figure': ('figure', 76), 'head': ('head', 116)}
# targetNode=('head', 117) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 40), 'chunk': ('chunk', 226), 'figure': ('figure', 77), 'head': ('head', 117)}
# targetNode=('head', 118) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 40), 'chunk': ('chunk', 227), 'figure': ('figure', 78), 'head': ('head', 118)}
# targetNode=('head', 120) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 41), 'chunk': ('chunk', 231), 'figure': ('figure', 79), 'head': ('head', 120)}
# targetNode=('head', 121) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 41), 'chunk': ('chunk', 232), 'figure': ('figure', 80), 'head': ('head', 121)}
# targetNode=('head', 123) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 42), 'chunk': ('chunk', 235), 'figure': ('figure', 81), 'head': ('head', 123)}
# targetNode=('head', 125) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 43), 'chunk': ('chunk', 238), 'figure': ('figure', 82), 'head': ('head', 125)}
# targetNode=('head', 128) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 45), 'chunk': ('chunk', 243), 'figure': ('figure', 83), 'head': ('head', 128)}
# targetNode=('head', 130) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 46), 'chunk': ('chunk', 245), 'figure': ('figure', 84), 'head': ('head', 130)}
# targetNode=('head', 132) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 47), 'chunk': ('chunk', 248), 'figure': ('figure', 85), 'head': ('head', 132)}
# targetNode=('head', 133) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 47), 'chunk': ('chunk', 250), 'figure': ('figure', 86), 'head': ('head', 133)}
# targetNode=('head', 134) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 47), 'chunk': ('chunk', 251), 'figure': ('figure', 87), 'head': ('head', 134)}
# targetNode=('head', 135) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 47), 'chunk': ('chunk', 252), 'figure': ('figure', 88), 'head': ('head', 135)}
# targetNode=('head', 136) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 47), 'chunk': ('chunk', 253), 'figure': ('figure', 89), 'head': ('head', 136)}
# targetNode=('head', 138) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 48), 'chunk': ('chunk', 255), 'figure': ('figure', 90), 'head': ('head', 138)}
# targetNode=('head', 140) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 49), 'chunk': ('chunk', 257), 'figure': ('figure', 91), 'head': ('head', 140)}
# targetNode=('head', 142) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 50), 'chunk': ('chunk', 260), 'figure': ('figure', 92), 'head': ('head', 142)}
# targetNode=('head', 144) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 51), 'chunk': ('chunk', 262), 'figure': ('figure', 93), 'head': ('head', 144)}
# targetNode=('head', 146) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 52), 'chunk': ('chunk', 265), 'figure': ('figure', 94), 'head': ('head', 146)}
# targetNode=('head', 148) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 53), 'chunk': ('chunk', 268), 'figure': ('figure', 95), 'head': ('head', 148)}
# targetNode=('head', 150) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 54), 'chunk': ('chunk', 273), 'figure': ('figure', 96), 'head': ('head', 150)}
# targetNode=('head', 152) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 55), 'chunk': ('chunk', 276), 'figure': ('figure', 97), 'head': ('head', 152)}
# targetNode=('head', 154) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 56), 'chunk': ('chunk', 279), 'figure': ('figure', 98), 'head': ('head', 154)}
# targetNode=('head', 156) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 57), 'chunk': ('chunk', 282), 'figure': ('figure', 99), 'head': ('head', 156)}
# targetNode=('head', 158) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 58), 'chunk': ('chunk', 285), 'figure': ('figure', 100), 'head': ('head', 158)}
# targetNode=('head', 160) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 59), 'chunk': ('chunk', 288), 'figure': ('figure', 101), 'head': ('head', 160)}
# targetNode=('head', 162) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 60), 'chunk': ('chunk', 291), 'figure': ('figure', 102), 'head': ('head', 162)}
# targetNode=('head', 163) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 60), 'chunk': ('chunk', 293), 'figure': ('figure', 103), 'head': ('head', 163)}
# targetNode=('head', 164) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 60), 'chunk': ('chunk', 294), 'figure': ('figure', 104), 'head': ('head', 164)}
# targetNode=('head', 165) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 60), 'chunk': ('chunk', 295), 'figure': ('figure', 105), 'head': ('head', 165)}
# targetNode=('head', 167) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'file': ('file', 1), 'about': ('about', 1), 'page': None, 'text': ('text', 1), 'body': ('body', 1), 'div': ('div', 61), 'chunk': ('chunk', 297), 'figure': ('figure', 106), 'head': ('head', 167)}
# 		   2 editem-about              about        Verantwoording_Notes_for_the_reader.xml
# targetNode=('head', 170) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'page': None, 'file': ('file', 2), 'about': ('about', 2), 'text': ('text', 2), 'body': ('body', 2), 'div': ('div', 63), 'chunk': ('chunk', 309), 'figure': ('figure', 107), 'head': ('head', 170)}
# targetNode=('head', 171) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'page': None, 'file': ('file', 2), 'about': ('about', 2), 'text': ('text', 2), 'body': ('body', 2), 'div': ('div', 63), 'chunk': ('chunk', 311), 'figure': ('figure', 108), 'head': ('head', 171)}
# targetNode=('head', 172) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'page': None, 'file': ('file', 2), 'about': ('about', 2), 'text': ('text', 2), 'body': ('body', 2), 'div': ('div', 63), 'chunk': ('chunk', 317), 'figure': ('figure', 109), 'head': ('head', 172)}
# targetNode=('head', 174) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'page': None, 'file': ('file', 2), 'about': ('about', 2), 'text': ('text', 2), 'body': ('body', 2), 'div': ('div', 64), 'chunk': ('chunk', 324), 'figure': ('figure', 110), 'head': ('head', 174)}
# targetNode=('head', 175) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'page': None, 'file': ('file', 2), 'about': ('about', 2), 'text': ('text', 2), 'body': ('body', 2), 'div': ('div', 64), 'chunk': ('chunk', 326), 'figure': ('figure', 111), 'head': ('head', 175)}
# targetNode=('head', 176) nodeType='head' cur[NODE]={'folder': ('folder', 1), 'page': None, 'file': ('file', 2), 'about': ('about', 2), 'text': ('text', 2), 'body': ('body', 2), 'div': ('div', 64), 'chunk': ('chunk', 332), 'figure': ('figure', 112), 'head': ('head', 176)}
# 		   3 editem-about              about        colofon.xml
# 		   4 editem-about              about        woord-van-dank.xml
#
# End   folder about
# 	Start folder letters:
# 		   5 editem-letter              letter       ii001.xml
# 		   6 editem-letter              letter       ii002.xml
# 		   7 editem-letter              letter       ii003.xml
# 		   8 editem-letter              letter       ii004.xml
# 		   9 editem-letter              letter       ii005.xml
# 		  24 editem-letter              letter       ii020.xml                                         targetNode=('head', 181) nodeType='head' cur[NODE]={'folder': ('folder', 2), 'file': ('file', 24), 'letter': ('letter', 20), 'text': ('text', 24), 'body': ('body', 24), 'div': ('div', 107), 'page': ('page', 76), 'chunk': ('chunk', 844), 'figure': ('figure', 113), 'head': ('head', 181)}
# targetNode=('head', 182) nodeType='head' cur[NODE]={'folder': ('folder', 2), 'file': ('file', 24), 'letter': ('letter', 20), 'text': ('text', 24), 'body': ('body', 24), 'div': ('div', 108), 'page': ('page', 79), 'chunk': ('chunk', 866), 'figure': ('figure', 114), 'head': ('head', 182)}
# 		  47 editem-letter              letter       ii043.xml                                         targetNode=('head', 183) nodeType='head' cur[NODE]={'folder': ('folder', 2), 'file': ('file', 47), 'letter': ('letter', 43), 'text': ('text', 47), 'body': ('body', 47), 'div': ('div', 153), 'page': ('page', 169), 'chunk': ('chunk', 1489), 'figure': ('figure', 115), 'head': ('head', 183)}
# targetNode=('head', 184) nodeType='head' cur[NODE]={'folder': ('folder', 2), 'file': ('file', 47), 'letter': ('letter', 43), 'text': ('text', 47), 'body': ('body', 47), 'div': ('div', 154), 'page': ('page', 170), 'chunk': ('chunk', 1498), 'figure': ('figure', 116), 'head': ('head', 184)}
# 		  53 editem-letter              letter       ii049.xml                                         targetNode=('head', 185) nodeType='head' cur[NODE]={'folder': ('folder', 2), 'file': ('file', 53), 'letter': ('letter', 49), 'text': ('text', 53), 'body': ('body', 53), 'div': ('div', 165), 'page': ('page', 191), 'chunk': ('chunk', 1645), 'figure': ('figure', 117), 'head': ('head', 185)}
# targetNode=('head', 186) nodeType='head' cur[NODE]={'folder': ('folder', 2), 'file': ('file', 53), 'letter': ('letter', 49), 'text': ('text', 53), 'body': ('body', 53), 'div': ('div', 166), 'page': ('page', 192), 'chunk': ('chunk', 1662), 'figure': ('figure', 118), 'head': ('head', 186)}
# 		 100 editem-letter              letter       ii096.xml                                         targetNode=('head', 187) nodeType='head' cur[NODE]={'folder': ('folder', 2), 'file': ('file', 100), 'letter': ('letter', 96), 'text': ('text', 100), 'body': ('body', 100), 'div': ('div', 259), 'page': ('page', 469), 'chunk': ('chunk', 2958), 'figure': ('figure', 119), 'head': ('head', 187)}
# targetNode=('head', 188) nodeType='head' cur[NODE]={'folder': ('folder', 2), 'file': ('file', 100), 'letter': ('letter', 96), 'text': ('text', 100), 'body': ('body', 100), 'div': ('div', 260), 'page': ('page', 473), 'chunk': ('chunk', 2976), 'figure': ('figure', 120), 'head': ('head', 188)}
# 		 107 editem-letter              letter       ii103.xml
# End   folder letters
# 	Start folder apparatus:
# 		 108 editem-artworklist              artworklist  artwork.xml
# 		 109 editem-bibliolist              bibliolist   bibliolist-en.xml
# 		 110 editem-bibliolist              bibliolist   bibliolist-nl.xml
# 		 111 editem-biolist              biolist      bio.xml
#
# End   folder apparatus
#
# Resolving links into edges ...
# 	956 in 2616 reference(s) resolved
# 	7 in 109 reference(s): could not be resolved
#    |     0.88s "delete" actions: 0
#    |     0.88s "edge" actions: 18153
#    |     0.88s "feature" actions: 235021
#    |     0.88s "node" actions: 20234
#    |     0.88s "resume" actions: 0
#    |     0.88s "slot" actions: 118212
#    |     0.88s "terminate" actions: 20337
#    |     138446 nodes of all types
#    |     0.89s OK
#    |     0.00s checking for nodes and edges ...
#    |     0.00s OK
#    |     0.00s checking (section) features ...
#    |     0.02s OK
#    |     0.00s reordering nodes ...
#    |     0.08s Max node = 138446
#    |     0.08s OK
#    |     0.00s reassigning feature values ...
#    |     0.06s OK
# True

# %% [markdown]
# # Step 3: Configure a TF app
#
# The TF app has configuration settings, a bit of custom code, and documentation.
# Most of it will be generated now, but there are ways to keep custom additions intact.

# %%
Tei.task(app=True)
# Out:
# App updated
# True

# %% [markdown]
# # Step 4: Use the new dataset
#
# The final proof that the conversion has worked is to load the data.
# On first-time loading several checks and pre-computations are performed.
# Next time the loading will be much quicker.

# %%
A = use(f"{Tei.org}/{Tei.repo}:clone", backend=Tei.backend, checkout="clone", silent="verbose", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/israels/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/israels/tf/0.3.0</span>
# This is Text-Fabric 13.0.10
# 68 features found and 0 ignored
#    |     0.04s T otype                from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.43s T oslots               from ~/github/HuygensING/israels/tf/0.3.0
#   0.47s Dataset without structure sections in otext:no structure functions in the T-API
#    |     0.00s T folder               from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.01s T chunk                from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T file                 from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.24s T after                from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.27s T str                  from ~/github/HuygensING/israels/tf/0.3.0
#    |      |     0.01s C __levels__           from otype, oslots, otext
#    |      |     0.86s C __order__            from otype, oslots, __levels__
#    |      |     0.03s C __rank__             from otype, __order__
#    |      |     0.97s C __levUp__            from otype, oslots, __rank__
#    |      |     0.18s C __levDown__          from otype, __levUp__, __rank__
#    |      |     0.03s C __characters__       from otext
#    |      |     0.28s C __boundary__         from otype, oslots, __rank__
#    |      |     0.04s C __sections__         from otype, oslots, otext, __levUp__, __levDown__, __levels__, folder, file, chunk
#   3.38s All features loaded / computed - for details use TF.isLoaded()
#    |     0.00s T artRef               from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T cert                 from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T commodity            from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T corresp              from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T correspondent        from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T dim                  from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T divRole              from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.01s T empty                from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.01s T extraspace           from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T f                    from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T facs                 from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T facsfile             from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T facsregion           from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T form                 from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T full                 from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.01s T id                   from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T inFigure             from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T institution          from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.02s T is_meta              from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.10s T is_note              from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T lang                 from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T level                from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T link_ref             from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T link_target          from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T location             from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T lrx                  from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T lry                  from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T msId                 from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.01s T n                    from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T name                 from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T notAfter             from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T notBefore            from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.05s T parent               from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T period               from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T periodLong           from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T personRef            from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T quantity             from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T ref                  from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T rend                 from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T rend_blockletter     from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.04s T rend_indent          from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.01s T rend_italics         from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T rend_right           from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T rend_sc              from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T rend_super           from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T rend_whiteline_above from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T sender               from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T sex                  from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T source               from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T status               from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T style                from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T target               from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T titleEn              from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T titleNl              from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.01s T type                 from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T ulx                  from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T uly                  from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T unit                 from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T url                  from ~/github/HuygensING/israels/tf/0.3.0
#    |     0.00s T when                 from ~/github/HuygensING/israels/tf/0.3.0
#   0.37s All additional features loaded - for details use TF.isLoaded()
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 13.0.10</a>, <a target="_blank" href="https://github.com/HuygensING/israels/blob/main/app" title="HuygensING/israels app">HuygensING/israels/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/HuygensING/israels/blob/main/docs/about.md" title="provenance of HuygensING - israels/tf">HuygensING - israels 0.3.0</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/HuygensING/israels/blob/main/docs/transcription.md" title="HuygensING - israels feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>folder</th>
#     <td>3</td>
#     <td>39404.00</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>about</th>
#     <td>4</td>
#     <td>5616.25</td>
#     <td>19</td>
# </tr>
#
# <tr>
#     <th>artworklist</th>
#     <td>1</td>
#     <td>5426.00</td>
#     <td>5</td>
# </tr>
#
# <tr>
#     <th>listObject</th>
#     <td>1</td>
#     <td>5388.00</td>
#     <td>5</td>
# </tr>
#
# <tr>
#     <th>bibliolist</th>
#     <td>2</td>
#     <td>1138.50</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>biolist</th>
#     <td>1</td>
#     <td>1101.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>file</th>
#     <td>111</td>
#     <td>1064.97</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>listPerson</th>
#     <td>1</td>
#     <td>1036.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>listBibl</th>
#     <td>2</td>
#     <td>946.50</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>letter</th>
#     <td>103</td>
#     <td>844.11</td>
#     <td>74</td>
# </tr>
#
# <tr>
#     <th>body</th>
#     <td>111</td>
#     <td>570.54</td>
#     <td>54</td>
# </tr>
#
# <tr>
#     <th>text</th>
#     <td>111</td>
#     <td>570.54</td>
#     <td>54</td>
# </tr>
#
# <tr>
#     <th>standOff</th>
#     <td>105</td>
#     <td>420.77</td>
#     <td>37</td>
# </tr>
#
# <tr>
#     <th>div</th>
#     <td>274</td>
#     <td>280.41</td>
#     <td>65</td>
# </tr>
#
# <tr>
#     <th>listAnnotation</th>
#     <td>416</td>
#     <td>106.20</td>
#     <td>37</td>
# </tr>
#
# <tr>
#     <th>quote</th>
#     <td>13</td>
#     <td>105.62</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>fileDesc</th>
#     <td>111</td>
#     <td>82.12</td>
#     <td>8</td>
# </tr>
#
# <tr>
#     <th>list</th>
#     <td>8</td>
#     <td>75.38</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>artwork</th>
#     <td>73</td>
#     <td>73.62</td>
#     <td>5</td>
# </tr>
#
# <tr>
#     <th>page</th>
#     <td>516</td>
#     <td>69.01</td>
#     <td>30</td>
# </tr>
#
# <tr>
#     <th>publicationStmt</th>
#     <td>111</td>
#     <td>44.43</td>
#     <td>4</td>
# </tr>
#
# <tr>
#     <th>lg</th>
#     <td>12</td>
#     <td>39.75</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>chunk</th>
#     <td>3526</td>
#     <td>33.46</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>teiHeader</th>
#     <td>111</td>
#     <td>93.68</td>
#     <td>9</td>
# </tr>
#
# <tr>
#     <th>bibl</th>
#     <td>58</td>
#     <td>32.71</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>titleStmt</th>
#     <td>111</td>
#     <td>30.79</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>p</th>
#     <td>3077</td>
#     <td>30.57</td>
#     <td>80</td>
# </tr>
#
# <tr>
#     <th>note</th>
#     <td>1358</td>
#     <td>35.25</td>
#     <td>40</td>
# </tr>
#
# <tr>
#     <th>figure</th>
#     <td>120</td>
#     <td>22.57</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>publisher</th>
#     <td>110</td>
#     <td>19.98</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>availability</th>
#     <td>110</td>
#     <td>19.85</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>licence</th>
#     <td>110</td>
#     <td>19.85</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>title</th>
#     <td>279</td>
#     <td>14.12</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>correspDesc</th>
#     <td>103</td>
#     <td>12.43</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>profileDesc</th>
#     <td>103</td>
#     <td>12.43</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>head</th>
#     <td>337</td>
#     <td>11.98</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>l</th>
#     <td>42</td>
#     <td>11.36</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>name</th>
#     <td>220</td>
#     <td>8.49</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>person</th>
#     <td>144</td>
#     <td>7.19</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>msDesc</th>
#     <td>103</td>
#     <td>7.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>sourceDesc</th>
#     <td>111</td>
#     <td>6.89</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>item</th>
#     <td>70</td>
#     <td>6.43</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>seg</th>
#     <td>5</td>
#     <td>6.40</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>correspAction</th>
#     <td>206</td>
#     <td>6.21</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>msIdentifier</th>
#     <td>103</td>
#     <td>6.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>persName</th>
#     <td>158</td>
#     <td>4.63</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>placeName</th>
#     <td>103</td>
#     <td>4.41</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>classDecl</th>
#     <td>1</td>
#     <td>4.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>encodingDesc</th>
#     <td>1</td>
#     <td>4.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>hi</th>
#     <td>1038</td>
#     <td>3.79</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>label</th>
#     <td>124</td>
#     <td>2.94</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>facsimile</th>
#     <td>103</td>
#     <td>2.93</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>rs</th>
#     <td>1425</td>
#     <td>2.50</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>ref</th>
#     <td>529</td>
#     <td>2.11</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>date</th>
#     <td>286</td>
#     <td>2.05</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>author</th>
#     <td>1</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>country</th>
#     <td>103</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>forename</th>
#     <td>156</td>
#     <td>1.49</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>surname</th>
#     <td>178</td>
#     <td>1.49</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>surface</th>
#     <td>217</td>
#     <td>1.39</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>idno</th>
#     <td>254</td>
#     <td>1.12</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>nameLink</th>
#     <td>23</td>
#     <td>1.09</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>addName</th>
#     <td>1</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>altIdentifier</th>
#     <td>103</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>birth</th>
#     <td>144</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>death</th>
#     <td>143</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>graphic</th>
#     <td>410</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>institution</th>
#     <td>103</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>lb</th>
#     <td>18</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>measure</th>
#     <td>120</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>objectDesc</th>
#     <td>103</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>physDesc</th>
#     <td>103</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>ptr</th>
#     <td>778</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>pubPlace</th>
#     <td>110</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>relation</th>
#     <td>53</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>settlement</th>
#     <td>103</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>space</th>
#     <td>546</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>taxonomy</th>
#     <td>4</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>zone</th>
#     <td>85</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th><i>t</i></th>
#     <td>118212</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <detai
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>TF API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>

# %% [markdown]
# # Step 5: Generate IIIF manifests

# %%
II = IIIF(Tei.teiVersion, A, Tei.reportPath, prod="dev", silent=False)
# Out:
# No cover directory: ~/github/HuygensING/israels/None/covers
# Scan images taken from ~/github/HuygensING/israels/None
# IIIF settings read from ~/github/HuygensING/israels/config/iiif.yml
# Manifestlevel = file
# All generated urls are for a dev deployment on http:/localhost:8087
# Size file not found: ~/github/HuygensING/israels/None/sizes_pages.tsv
# Rotation file not found: ~/github/HuygensING/israels/None/rotation_pages.tsv
# Using facs file info file ~/github/HuygensING/israels/report/2025-07-02/facs.yml
# Using facs mapping file ~/github/HuygensING/israels/report/2025-07-02/facsMapping.yml
# Collections:
#      about with    4 files and    0 pages
#      intro with    1 files and    0 pages (excluded in config)
#    letters with  103 files and  510 pages
#  apparatus with    4 files and    0 pages

# %%
II.manifests()
# Out:
# Directory with logos not found: ~/github/HuygensING/israels/None/logo
# Missing image files:
# 	pages:
# 		ii001:
# 			  2 x b8564V2008_b
# 		ii002:
# 			  2 x b8579V2008v_vs_b
# 			  2 x b8579V2008r_b
# 		ii003:
# 			  2 x b8575V2008_b
# 		ii004:
# 			  2 x b8580V2008v_vs_b
# 			  2 x b8580V2008r_b
# 		ii005:
# 			  2 x b8581V2008v_vs_b
# 			  2 x b8581V2008r_b
# 		ii006:
# 			  2 x b8582V2008v_vs_b
# 			  2 x b8582V2008r_b
# 		ii007:
# 			  2 x b8574V2008_b
# 		ii008:
# 			  4 x b8565V2008_b
# 		ii009:
# 			  2 x b8629V2008r_b
# 			  2 x b8629V2008v_vs_b
# 		ii010:
# 			  4 x b8572V2008r_b
# 			  4 x b8572V2008v_vs_b
# 		ii011:
# 			  2 x b8570V2008r_b
# 			  2 x b8570V2008v_vs_b
# 		ii012:
# 			  4 x b8571V2008_b
# 		ii013:
# 			  2 x b8569V2008_b
# 		ii014:
# 			  2 x b8578V2008v_vs_b
# 			  2 x b8578V2008r_b
# 		ii015:
# 			  2 x b8568V2008r_b
# 			  2 x b8568V2008v_vs_b
# 		ii016:
# 			  2 x b8666V2008_b
# 		ii017:
# 			  4 x b8573V2008_b
# 		ii018:
# 			  4 x b8662V2008_b
# 		ii019:
# 			  2 x b8652V2008_b
# 		ii020:
# 			  2 x b8576V2008r_b
# 			  4 x b8576V2008v_vs_b
# 		ii021:
# 			  2 x b8577V2008_b
# 		ii022:
# 			  4 x b8567V2008_b
# 		ii023:
# 			  2 x b8588V2008_b
# 		ii024:
# 			  2 x b8589V2008_b
# 		ii025:
# 			  2 x b8657V2008_b
# 		ii026:
# 			  2 x b8660V2008_b
# 		ii027:
# 			  2 x b8656V2008_b
# 		ii028:
# 			  2 x b8587-001V2008_b
# 			  2 x b8587-002V2008_b
# 			  2 x b8587-002V2008_vs_b
# 		ii029:
# 			  4 x b8566V2008_b
# 			  4 x NOTFOUND
# 		ii030:
# 			  4 x b8585V2008_b
# 		ii031:
# 			  2 x b8584V2008_b
# 		ii032:
# 			  2 x b8594-001V2008_b
# 			  2 x b8594-002V2008_b
# 			  2 x b8594-002V2008_vs_b
# 		ii033:
# 			  2 x b8586V2008r_b
# 			  2 x b8586V2008v_vs_b
# 		ii034:
# 			  2 x b8595V2008v_vs_b
# 			  2 x b8595V2008r_b
# 		ii035:
# 			  4 x b8583V2008r_b
# 			  4 x b8583V2008v_vs_b
# 		ii036:
# 			  4 x b8644V2008v_vs_b
# 		ii095:
# 			  4 x b8645V2008v_vs_b
# 			  2 x b8645V2008r_b
# 		ii096:
# 			  4 x b8646V2008r_b
# 			  4 x b8646V2008v_vs_b
# 		ii097:
# 			  2 x b8647V2008r_b
# 			  2 x b8647V2008v_vs_b
# 		ii098:
# 			  4 x b8648V2008r_b
# 			  4 x b8648V2008v_vs_b
# 		ii099:
# 			  2 x b8641V2008r_b
# 			  4 x b8641V2008v_vs_b
# 		ii100:
# 			  2 x b8643V2008r_b
# 			  2 x b8643V2008v_vs_b
# 		ii101:
# 			  2 x b8649V2008v_vs_b
# 			  2 x b8649V2008r_b
# 		ii102:
# 			  4 x b8650V2008v_vs_b
# 			  2 x b8650V2008r_b
# 		ii103:
# 			  2 x b8651-001V2008r_b
# 			  2 x b8651-001V2008v_vs_b
# 			  2 x b8651-002V2008_b
# 			  2 x b8651-002V2008_vs_b
# 	total occurrences of a missing file: 510
# 103 IIIF manifests with 103 items for 510 pages generated in ~/github/HuygensING/israels/static/2025-07-02/dev/manifests

# %% [markdown]
# # Step 6 Convert to WATM

# %% [markdown]
# N.B. For docs click the WATM link in the output cell.

# %%
WA = WATM(A, "tei", skipMeta=False, prod="preview", pageInfoDir=Tei.reportPath, extra=dict(), silent=False)
WA.makeText()
WA.makeAnno()
WA.writeAll()
# Out:
# conversion settings read from ~/github/HuygensING/israels/config/watm.yml
# IIIF settings read from ~/github/HuygensING/israels/config/iiif.yml
# Manifestlevel = file
# textRepoLevel is section level 'file'
# Top level exclusions:
# 	  1 node with folder=apparatus
# Excluded nodes: 11443 from 162749 nodes
# Using facs file info file ~/github/HuygensING/israels/report/2025-07-02/facs.yml
# Using facs mapping file ~/github/HuygensING/israels/report/2025-07-02/facsMapping.yml
# [WATM exporter documentation](https://annotation.github.io/text-fabric-factory/tff/convert/watm.html)
# No cover directory: ~/github/HuygensING/israels/scans/covers
# Maximum dimensions: W = 8272 H = 8272
# Average dimensions: W = 7966 H = 6340
# Average deviation:  W =  541 H =  370
# Skipping file node 146416 because folder=apparatus
# Skipping file node 146417 because folder=apparatus
# Skipping file node 146418 because folder=apparatus
# Skipping file node 146419 because folder=apparatus
# DATA warnings
# 	 103x letter:canvasUrl: substituted filenotfound
# 		   1x ii001: b8564V2008_b
# 		   1x ii002: b8579V2008v_vs_b
# 		   1x ii003: b8575V2008_b
# 		   1x ii004: b8580V2008v_vs_b
# 		   1x ii005: b8581V2008v_vs_b
# 		   1x ii006: b8582V2008v_vs_b
# 		   1x ii007: b8574V2008_b
# 		   1x ii008: b8565V2008_b
# 		   1x ii009: b8629V2008r_b
# 		   1x ii010: b8572V2008r_b
# 		   1x ii011: b8570V2008r_b
# 		   1x ii012: b8571V2008_b
# 		   1x ii013: b8569V2008_b
# 		   1x ii014: b8578V2008v_vs_b
# 		   1x ii015: b8568V2008r_b
# 		   1x ii016: b8666V2008_b
# 		   1x ii017: b8573V2008_b
# 		   1x ii018: b8662V2008_b
# 		   1x ii019: b8652V2008_b
# 		   1x ii020: b8576V2008r_b
# 		   1x ii021: b8577V2008_b
# 		   2x ii103: b8651-001V2008r_b
# 		   2x ii103: b8651-001V2008v_vs_b
# 		   2x ii103: b8651-002V2008_b
# 		   2x ii103: b8651-002V2008_vs_b
# WARNING: targets across file items, 2x
#               folder [   0:     0] - [   3:   600]
#               folder [   5:     0] - [ 107:  1227]
# 	Writing WATM ...
# Writing preview data to ~/github/HuygensING/israels/watm/0.2.0/preview
# Text file    0:    18691 segments to ~/github/HuygensING/israels/watm/0.2.0/preview/text-0.tsv
# Text file    1:     2672 segments to ~/github/HuygensING/israels/watm/0.2.0/preview/text-1.tsv
# Text file    2:      501 segments to ~/github/HuygensING/israels/watm/0.2.0/preview/text-2.tsv
# Text file    3:      602 segments to ~/github/HuygensING/israels/watm/0.2.0/preview/text-3.tsv
# Text file    4:    22203 segments to ~/github/HuygensING/israels/watm/0.2.0/preview/text-4.tsv
# Text file  107:     1229 segments to ~/github/HuygensING/israels/watm/0.2.0/preview/text-107.tsv
# Text files all:   131494 segments to 108 files
# Anno file    1:   162765 annotations written to ~/github/HuygensING/israels/watm/0.2.0/preview/anno-1.tsv
# Inherited annotations: 0
# Anno files all:   162765 annotations to 1 file
# Slot mapping written to ~/github/HuygensING/israels/watm/0.2.0/preview/pos2node.tsv
# Node mapping written to ~/github/HuygensING/israels/watm/0.2.0/preview/anno2node.tsv

# %% [markdown]
# # Step 7 Test the WATM against the TF

# %%
WA.error = False
WA.testAll()
# Out:
# 	Testing WATM ...
# Excluded nodes: 37388 from 139841 nodes
# Testing the text ...
# 	TF:  87121
# 	WA:  87121
# OK - whether the amounts of tokens agree
# 	TF: Isaac Israëls aan Jo ... s from letter 082.
# 	WA: Isaac Israëls aan Jo ... s from letter 082.
# OK - whether the text is the same
# Testing the elements ...
# 	TF:  12463
# 	WA:  12463
# OK - whether the amounts of elements and nodes agree
# Testing the processing instructions ...
# 	TF:      0
# 	WA:      0
# OK - whether the amounts of processing instructions agree
# Testing the element/pi annotations ...
# 	12463 element/pi annotations
# 	Element      :  12463 x
# 	Pi           :      0 x
# 	Good name    :  12463 x
# 	Wrong name   :      0 x
# 	Good target  :  12463 x
# 	Wrong target :      0 x
# 	Unmapped     :      0 x
# OK - whether all element/pi annotations have good bodies
# OK - whether all element/pi annotations have good targets
# Testing the attributes ...
# 	37262 attribute values
# 	Good:     37262 x
# 	Wrong:        0 x
# OK - whether annotations are consistent with features
# 	WA attributes: 37262
# 	TF attributes: 37262
# OK - whether annotations are complete w.r.t. features
# Testing the format attributes ...
# 	18994 format values
# 	formatting attributes:
# 		 16715 x indent
# 		  2139 x italics
# 		   114 x blockletter
# 		    26 x super
# 	Good:     18994 x
# 	Wrong:        0 x
# OK - whether format annotations are consistent with features
# 	WA format attributes: 18994
# 	TF format attributes: 18994
# OK - whether format annotations are complete w.r.t. features
# Testing the extra annotations ...
# 	0 extra feature values
# 	0 extra annotations
# OK - whether the extra annotations agree
# Testing the edges ...
# 	Found: 2 edges in annotations
# 		edge link_target with 825 starting nodes
# 		edge parent with 11378 starting nodes
# 	Found: 2 edges in annotations
# 		edge link_target with 825 starting nodes
# 		edge parent with 11378 starting nodes
# 	Checking edge parent
# 		same 11378 fromNodes
# 		OK - 11378 toNodes checked
# 	Checking edge link_target
# 		same 825 fromNodes
# 		OK - 825 toNodes checked
# OK - whether all edges agree
# Overall outcome ...
# OK - whether all tests passed
