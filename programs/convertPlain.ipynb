# %% [markdown]
# # Convert from TEI to TF to WATM
#
# First we convert the corpus TEI to TF and then the TF to WATM.
#
# This notebook is bare, no explanations, no illustrations, no checks.
# For more documentation, try any of the following variants:

# %% [markdown]
# # Step by step
#
# Below you can inspect all the steps of the conversion:

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use
from tff.convert.tei import TEI
from tff.convert.addnlp import NLPipeline
from tff.convert.watm import WATM
from tff.convert.iiif import IIIF
from tff.convert.scans import Scans
from tf.advanced.helpers import dm

# %% [markdown]
# ## Step 0: Scan ingest

# %%
SC = Scans(verbose=1, force=False)
# Out:
# Working in repository HuygensING/israels in back-end github
# Source dir = ~/github/HuygensING/israels
# imageprep settings read from ~/github/HuygensING/israels/config/scans.yml

# %% [markdown]
# ## Step 2: Scan processing

# %%
# SC.process(force=True)
SC.process(force=False)
# Out:
# 	Convert 4 originals to thumbnails (pages)
# 		100% done
# 	Get sizes of 4 thumbnails (pages)
# 		100% done
# 	Get sizes of 4 originals (pages)
# 		100% done
# originals: 4
# thumbnails: 4

# %%
Tei = TEI(verbose=-1, tei="2025-03-25", tf="0.0.1")
# Tei = TEI(verbose=-1, tei="2025-02-25-subset", tf="0.0.1s")

# %% [markdown]
# # Step 1: Check

# %%
Tei.task(check=True, verbose=1, validate=True, carryon=True)
# Out:
# TEI to TF checking: ~/github/HuygensING/israels/tei/2025-03-25 => ~/github/HuygensING/israels/report/2025-03-25
# Processing instructions are treated
# XML validation will be performed
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/israels/schema/editem-about.xsd
# 	round   1:  52 changes
# 118 identical override(s)
#   0 changing override(s)
# INFO: Needs editem.xsd (exists)
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/israels/schema/editem-letter.xsd
# Warning: tei:tei_model.divBottom.kind is not defined.
# Warning: tei:tei_model.divBottom.kind is not defined.
# 	round   1:  71 changes
# Warning: tei:tei_model.divBottom.kind is not defined.
# Warning: tei:tei_model.divBottom.kind is not defined.
# 172 identical override(s)
#   2 changing override(s)
# 	artwork complex pure (added)
# 	eventName complex mixed (added)
# INFO: Needs editem.xsd (exists)
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/israels/schema/editem-artworklist.xsd
# 	round   1:  21 changes
# 	round   2:   2 changes
#  29 identical override(s)
#   3 changing override(s)
# 	artwork complex pure (added)
# 	bibl mixed ==> pure
# 	catRef pure ==> mixed
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/israels/schema/editem-biolist.xsd
# 	round   1:  33 changes
# 	round   2:   4 changes
#  37 identical override(s)
#   0 changing override(s)
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/israels/schema/editem-bibliolist.xsd
# 	round   1:  16 changes
#  26 identical override(s)
#   0 changing override(s)
# Section model I
# 	Start folder about
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/about/Inleiding_introduction.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/about/Verantwoording_Notes_for_the_reader.xml
# 	Start folder letters
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii001.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii002.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii003.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii004.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii005.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii006.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii007.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii008.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii009.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii010.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii011.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii012.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii013.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii014.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii015.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii016.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii017.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii018.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii019.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii020.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii021.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii022.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii023.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii024.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii025.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii026.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii027.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii028.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii029.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii030.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii031.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii032.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii033.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii034.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii035.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii036.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii037.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii038.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii039.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii040.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii041.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii042.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii043.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii044.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii045.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii046.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii047.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii048.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii049.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii050.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii051.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii052.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii053.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii054.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii055.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii056.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii057.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii058.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii059.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii060.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii061.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii062.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii063.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii064.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii065.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii066.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii067.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii068.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii069.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii070.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii071.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii072.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii073.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii074.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii075.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii076.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii077.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii078.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii079.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii080.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii081.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii082.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii083.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii084.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii085.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii086.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii087.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii088.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii089.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii090.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii091.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii092.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii093.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii094.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii095.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii096.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii097.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii098.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii099.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii100.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii101.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii102.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii103.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii80.xml
# 	Start folder apparatus
# unavailable model editem-artwork in ~/github/HuygensING/israels/tei/2025-03-25/apparatus/artwork.xml
# 3 TEI file(s) ...
# 	Validating ...
# 	Making inventory ...
# 2 editem-about file(s) ...
# 	Validating ...
# 	Making inventory ...
# 104 editem-letter file(s) ...
# 	Validating ...
# 	Making inventory ...
# 2 editem-bibliolist file(s) ...
# 	Validating ...
# 	Making inventory ...
# 1 editem-biolist file(s) ...
# 	Validating ...
# 	Making inventory ...
#
# 586 tag(s) type info written to ~/github/HuygensING/israels/report/2025-03-25/types.txt
# 1919 validation error(s) in 37 file(s) written to ~/github/HuygensING/israels/report/2025-03-25/errors.txt
# 0 pagebreaks without facs attribute.
# 514 pagebreaks encountered.
# 257 distinct scans referred to by pagebreaks.
# 183 surfaces declared
# 0 zones declared
# 183 scans declared and mapped.
# 78 undeclared scans
# 4 unused scans of which 4 surfaces and 0 zones
# 0 processing instructions encountered.
# 80 tags of which 0 with multiple namespaces written to ~/github/HuygensING/israels/report/2025-03-25/namespaces.txt
# 330 info line(s) written to ~/github/HuygensING/israels/report/2025-03-25/elements.txt
# Refs written to ~/github/HuygensING/israels/report/2025-03-25/refs.txt
# 	resolvable:  670 in  670
# 	dangling:    282 in 1922
# 	ALL:         952 in 2592
# Ids written to ~/github/HuygensING/israels/report/2025-03-25/ids.txt
# 	referenced:  670 by  670
# 	non-unique:    0
# 	unused:     3406
# 	ALL:        4076 in 4076
# lb-parent info written to ~/github/HuygensING/israels/report/2025-03-25/lb-parents.txt
# False

# %% [markdown]
# # Step 2: Convert

# %%
Tei.good = True

# %%
Tei.task(convert=True, verbose=0)
# Out:
# Page model II with page nodes for pages started by pb elements without keeping the pb elements
# Section model I
# Processing instructions are treated
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/israels/schema/editem-about.xsd
# 	round   1:  52 changes
# 118 identical override(s)
#   0 changing override(s)
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/israels/schema/editem-letter.xsd
# Warning: tei:tei_model.divBottom.kind is not defined.
# Warning: tei:tei_model.divBottom.kind is not defined.
# 	round   1:  71 changes
# Warning: tei:tei_model.divBottom.kind is not defined.
# Warning: tei:tei_model.divBottom.kind is not defined.
# 172 identical override(s)
#   2 changing override(s)
# 	artwork complex pure (added)
# 	eventName complex mixed (added)
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/israels/schema/editem-artworklist.xsd
# 	round   1:  21 changes
# 	round   2:   2 changes
#  29 identical override(s)
#   3 changing override(s)
# 	artwork complex pure (added)
# 	bibl mixed ==> pure
# 	catRef pure ==> mixed
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/israels/schema/editem-biolist.xsd
# 	round   1:  33 changes
# 	round   2:   4 changes
#  37 identical override(s)
#   0 changing override(s)
# Analysing ~/github/annotation/text-fabric-factory/tff/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/israels/schema/editem-bibliolist.xsd
# 	round   1:  16 changes
#  26 identical override(s)
#   0 changing override(s)
#   0.00s Importing data from walking through the source ...
#    |     0.00s Preparing metadata...
#    |     0.00s OK
#    |     0.00s Following director...
# 	Start folder about:
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/about/Inleiding_introduction.xml
# 		   1 TEI                       letter       Inleiding_introduction.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/about/Verantwoording_Notes_for_the_reader.xml
# 		   2 TEI                       letter       Verantwoording_Notes_for_the_reader.xml
# 		   3 editem-about              about        colofon.xml
# 		   4 editem-about              about        woord-van-dank.xml
#
# End   folder about
# 	Start folder letters:
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii001.xml
# 		   5 editem-letter              letter       ii001.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii002.xml
# 		   6 editem-letter              letter       ii002.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii003.xml
# 		   7 editem-letter              letter       ii003.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii004.xml
# 		   8 editem-letter              letter       ii004.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii005.xml
# 		   9 editem-letter              letter       ii005.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii006.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii007.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii008.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii009.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii010.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii011.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii012.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii013.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii014.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii015.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii016.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii017.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii018.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii019.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii020.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii021.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii022.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii023.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii024.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii025.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii026.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii027.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii028.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii029.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii030.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii031.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii032.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii033.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii034.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii035.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii036.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii037.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii038.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii039.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii040.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii041.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii042.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii043.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii044.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii045.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii046.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii047.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii048.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii049.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii050.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii051.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii052.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii053.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii054.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii055.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii056.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii057.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii058.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii059.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii060.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii061.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii062.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii063.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii064.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii065.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii066.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii067.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii068.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii069.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii070.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii071.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii072.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii073.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii074.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii075.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii076.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii077.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii078.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii079.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii080.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii081.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii082.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii083.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii084.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii085.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii086.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii087.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii088.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii089.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii090.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii091.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii092.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii093.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii094.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii095.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii096.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii097.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii098.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii099.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii100.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii101.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii102.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii103.xml
# unavailable adaptation md in ~/github/HuygensING/israels/tei/2025-03-25/letters/ii80.xml
#
# End   folder letters
# 	Start folder apparatus:
# unavailable model editem-artwork in ~/github/HuygensING/israels/tei/2025-03-25/apparatus/artwork.xml
# 		 109 TEI                       artworklist  artwork.xml
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `photograph`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `photograph`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `photograph`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `photograph`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `photograph`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `photograph`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `document`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `photograph`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `photograph`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `photograph`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `photograph`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `photograph`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `photograph`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `photograph`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `photograph`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `photograph`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `photograph`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `document`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `document`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `document`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# WARNING: Text material at the start of pure-content element <catRef>
# 	Element stack: TEI-text-body-listObject-artwork-catRef
# 	Material: `artwork`
# 		 110 editem-bibliolist              bibliolist   bibliolist-en.xml
# 		 111 editem-bibliolist              bibliolist   bibliolist-nl.xml
# 		 112 editem-biolist              bibliolist   biolist.xml
#
# End   folder apparatus
#
# Resolving links into edges ...
# 	767 in 1117 reference(s) resolved
# 	185 in 1475 reference(s): could not be resolved
#    |     0.92s "delete" actions: 0
#    |     0.92s "edge" actions: 17063
#    |     0.92s "feature" actions: 239102
#    |     0.92s "node" actions: 20665
#    |     0.92s "resume" actions: 0
#    |     0.92s "slot" actions: 120564
#    |     0.92s "terminate" actions: 20773
#    |     141229 nodes of all types
#    |     0.93s OK
#    |     0.00s Removing unlinked (of which 0 deleted) nodes ...
#    |      |     0.00s     54 unlinked "page" nodes: [93, 96, 113, 116, 141] ...
#    |      |     0.00s     54 unlinked nodes
#    |      |     0.00s Leaving 141175 nodes
#    |     0.00s checking for nodes and edges ...
#    |     0.00s OK
#    |     0.00s checking (section) features ...
#    |     0.01s OK
#    |     0.00s reordering nodes ...
#    |     0.13s Max node = 141175
#    |     0.13s OK
#    |     0.00s reassigning feature values ...
#    |     0.05s OK
# True

# %% [markdown]
# # Step 3: Configure a TF app
#
# The TF app has configuration settings, a bit of custom code, and documentation.
# Most of it will be generated now, but there are ways to keep custom additions intact.

# %%
Tei.task(app=True)
# Out:
# True

# %% [markdown]
# # Step 4: Use the new dataset
#
# The final proof that the conversion has worked is to load the data.
# On first-time loading several checks and pre-computations are performed.
# Next time the loading will be much quicker.

# %%
A = use(f"{Tei.org}/{Tei.repo}:clone", backend=Tei.backend, checkout="clone", silent="verbose", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/israels/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/israels/tf/0.0.1</span>
# This is Text-Fabric 13.0.6
# 72 features found and 0 ignored
#    |     0.03s T otype                from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.38s T oslots               from ~/github/HuygensING/israels/tf/0.0.1
#   0.41s Dataset without structure sections in otext:no structure functions in the T-API
#    |     0.28s T str                  from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T file                 from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.24s T after                from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.01s T chunk                from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T folder               from ~/github/HuygensING/israels/tf/0.0.1
#    |      |     0.01s C __levels__           from otype, oslots, otext
#    |      |     0.85s C __order__            from otype, oslots, __levels__
#    |      |     0.03s C __rank__             from otype, __order__
#    |      |     0.91s C __levUp__            from otype, oslots, __rank__
#    |      |     0.18s C __levDown__          from otype, __levUp__, __rank__
#    |      |     0.03s C __characters__       from otext
#    |      |     0.25s C __boundary__         from otype, oslots, __rank__
#    |      |     0.04s C __sections__         from otype, oslots, otext, __levUp__, __levDown__, __levels__, folder, file, chunk
#   3.23s All features loaded / computed - for details use TF.isLoaded()
#    |     0.00s T cert                 from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T commodity            from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T corresp              from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T correspondent        from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T default              from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T dim                  from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T divRole              from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.01s T empty                from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.02s T extraspace           from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T f                    from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T facs                 from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T facsfile             from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T facsregion           from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T form                 from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T full                 from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.01s T id                   from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T ident                from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T institution          from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.02s T is_meta              from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.10s T is_note              from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T lang                 from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T level                from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T link_target          from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T location             from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T lrx                  from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T lry                  from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T msId                 from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.01s T n                    from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T name                 from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T notBefore            from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.05s T parent               from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T period               from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T periodLong           from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T pieter               from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T quantity             from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T ref                  from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T rend                 from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T rend_Citaat          from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T rend_Endnote_Anchor  from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T rend_Illustratie_onderschrift from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T rend_Paragraafkop    from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T rend_Subparagraafkop from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T rend__               from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T rend_blockletter     from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.04s T rend_indent          from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T rend_ingesprongen    from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.01s T rend_italics         from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T rend_rechtsuitlijnend from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T rend_super           from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T rend_whiteline_above from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T scheme               from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T sender               from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T sex                  from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T source               from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T status               from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T style                from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T target               from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.01s T type                 from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T ulx                  from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T uly                  from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T unit                 from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T url                  from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T version              from ~/github/HuygensING/israels/tf/0.0.1
#    |     0.00s T when                 from ~/github/HuygensING/israels/tf/0.0.1
#   0.36s All additional features loaded - for details use TF.isLoaded()
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 13.0.6</a>, <a target="_blank" href="https://github.com/HuygensING/israels/blob/main/app" title="HuygensING/israels app">HuygensING/israels/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/HuygensING/israels/blob/main/docs/about.md" title="provenance of HuygensING - israels/tf">HuygensING - israels 0.0.1</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/HuygensING/israels/blob/main/docs/transcription.md" title="HuygensING - israels feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>folder</th>
#     <td>3</td>
#     <td>40188.00</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>artworklist</th>
#     <td>1</td>
#     <td>7904.00</td>
#     <td>7</td>
# </tr>
#
# <tr>
#     <th>listObject</th>
#     <td>1</td>
#     <td>7858.00</td>
#     <td>7</td>
# </tr>
#
# <tr>
#     <th>bibliolist</th>
#     <td>3</td>
#     <td>1487.00</td>
#     <td>4</td>
# </tr>
#
# <tr>
#     <th>file</th>
#     <td>112</td>
#     <td>1076.46</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>listPerson</th>
#     <td>1</td>
#     <td>1024.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>letter</th>
#     <td>106</td>
#     <td>1010.85</td>
#     <td>89</td>
# </tr>
#
# <tr>
#     <th>body</th>
#     <td>112</td>
#     <td>604.32</td>
#     <td>56</td>
# </tr>
#
# <tr>
#     <th>text</th>
#     <td>112</td>
#     <td>604.32</td>
#     <td>56</td>
# </tr>
#
# <tr>
#     <th>about</th>
#     <td>2</td>
#     <td>524.50</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>list</th>
#     <td>8</td>
#     <td>459.75</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>standOff</th>
#     <td>106</td>
#     <td>416.30</td>
#     <td>37</td>
# </tr>
#
# <tr>
#     <th>div</th>
#     <td>216</td>
#     <td>256.75</td>
#     <td>46</td>
# </tr>
#
# <tr>
#     <th>quote</th>
#     <td>3</td>
#     <td>167.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>artwork</th>
#     <td>73</td>
#     <td>107.45</td>
#     <td>7</td>
# </tr>
#
# <tr>
#     <th>listAnnotation</th>
#     <td>418</td>
#     <td>105.57</td>
#     <td>37</td>
# </tr>
#
# <tr>
#     <th>page</th>
#     <td>460</td>
#     <td>78.03</td>
#     <td>30</td>
# </tr>
#
# <tr>
#     <th>fileDesc</th>
#     <td>112</td>
#     <td>63.84</td>
#     <td>6</td>
# </tr>
#
# <tr>
#     <th>bibl</th>
#     <td>80</td>
#     <td>41.11</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>lg</th>
#     <td>12</td>
#     <td>39.75</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>chunk</th>
#     <td>3544</td>
#     <td>34.00</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>teiHeader</th>
#     <td>112</td>
#     <td>75.81</td>
#     <td>7</td>
# </tr>
#
# <tr>
#     <th>titleStmt</th>
#     <td>112</td>
#     <td>30.37</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>p</th>
#     <td>3286</td>
#     <td>29.20</td>
#     <td>80</td>
# </tr>
#
# <tr>
#     <th>note</th>
#     <td>1539</td>
#     <td>32.00</td>
#     <td>41</td>
# </tr>
#
# <tr>
#     <th>publicationStmt</th>
#     <td>112</td>
#     <td>26.51</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>publisher</th>
#     <td>110</td>
#     <td>20.00</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>change</th>
#     <td>2</td>
#     <td>14.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>listChange</th>
#     <td>2</td>
#     <td>14.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>revisionDesc</th>
#     <td>2</td>
#     <td>14.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>title</th>
#     <td>380</td>
#     <td>12.61</td>
#     <td>4</td>
# </tr>
#
# <tr>
#     <th>correspDesc</th>
#     <td>104</td>
#     <td>12.42</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>profileDesc</th>
#     <td>104</td>
#     <td>12.42</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>l</th>
#     <td>42</td>
#     <td>11.36</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>name</th>
#     <td>222</td>
#     <td>8.44</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>head</th>
#     <td>86</td>
#     <td>8.37</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>classDecl</th>
#     <td>2</td>
#     <td>7.50</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>person</th>
#     <td>143</td>
#     <td>7.16</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>edition</th>
#     <td>2</td>
#     <td>7.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>editionStmt</th>
#     <td>2</td>
#     <td>7.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>msDesc</th>
#     <td>104</td>
#     <td>7.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>sourceDesc</th>
#     <td>112</td>
#     <td>6.84</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>seg</th>
#     <td>5</td>
#     <td>6.40</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>correspAction</th>
#     <td>208</td>
#     <td>6.21</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>msIdentifier</th>
#     <td>104</td>
#     <td>6.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>item</th>
#     <td>48</td>
#     <td>5.50</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>hi</th>
#     <td>1289</td>
#     <td>5.26</td>
#     <td>6</td>
# </tr>
#
# <tr>
#     <th>encodingDesc</th>
#     <td>4</td>
#     <td>5.25</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>persName</th>
#     <td>156</td>
#     <td>4.63</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>placeName</th>
#     <td>104</td>
#     <td>4.40</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>appInfo</th>
#     <td>2</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>application</th>
#     <td>2</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>availability</th>
#     <td>110</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>licence</th>
#     <td>110</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>taxonomy</th>
#     <td>5</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>label</th>
#     <td>126</td>
#     <td>2.94</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>facsimile</th>
#     <td>104</td>
#     <td>2.51</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>rs</th>
#     <td>1273</td>
#     <td>2.39</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>ref</th>
#     <td>537</td>
#     <td>2.08</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>author</th>
#     <td>5</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>country</th>
#     <td>104</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>date</th>
#     <td>364</td>
#     <td>1.77</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>forename</th>
#     <td>155</td>
#     <td>1.50</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>surname</th>
#     <td>177</td>
#     <td>1.49</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>surface</th>
#     <td>220</td>
#     <td>1.19</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>nameLink</th>
#     <td>23</td>
#     <td>1.09</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>addName</th>
#     <td>1</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>altIdentifier</th>
#     <td>104</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>birth</th>
#     <td>143</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>catDesc</th>
#     <td>3</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>catRef</th>
#     <td>73</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>category</th>
#     <td>3</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>death</th>
#     <td>142</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>graphic</th>
#     <td>390</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>idno</th>
#     <td>208</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>institution</th>
#     <td>104</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>lb</th>
#     <td>18</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>measure</th>
#     <td>208</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>objectDesc</th>
#     <td>104</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>physDesc</th>
#     <td>104</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>ptr</th>
#     <td>784</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>pubPlace</th>
#     <td>11
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>TF API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>

# %% [markdown]
# # Step 5: Generate IIIF manifests

# %%
II = IIIF(Tei.teiVersion, A, Tei.reportPath, prod="dev", silent=False)
# Out:
# No cover directory: ~/github/HuygensING/israels/thumb/covers
# IIIF settings read from ~/github/HuygensING/israels/config/iiif.yml
# Manifestlevel = file
# Maximum dimensions: W = 2895 H = 2895
# Average dimensions: W = 2821 H = 2235
# Average deviation:  W =  134 H =  120
# Rotation file not found: ~/github/HuygensING/israels/thumb/rotation_pages.tsv
# Using facs file info file ~/github/HuygensING/israels/report/2025-03-25/facs.yml
# Using facs mapping file ~/github/HuygensING/israels/report/2025-03-25/facsMapping.yml
# Collections:
#      about with    4 files and    0 pages
#    letters with  104 files and  514 pages
#  apparatus with    4 files and    0 pages

# %%
II.manifests()
# Out:
# 104 IIIF manifests with 166 items for 514 pages generated in ~/github/HuygensING/israels/static/2025-03-25/dev/manifests

# %% [markdown]
# # Step 6 Convert to WATM

# %% [markdown]
# N.B. For docs click the WATM link in the output cell.

# %%
WA = WATM(A, "tei", skipMeta=False, extra=dict(), silent=False)
WA.makeText()
WA.makeAnno()
WA.writeAll()
# Out:
# conversion settings read from ~/github/HuygensING/israels/config/watm.yml
# IIIF settings read from ~/github/HuygensING/israels/config/iiif.yml
# textRepoLevel is section level 'file'
# [WATM exporter documentation](https://annotation.github.io/text-fabric-factory/tff/convert/watm.html)
# No cover directory: ~/github/HuygensING/israels/thumb/covers
# Maximum dimensions: W = 2895 H = 2895
# Average dimensions: W = 2821 H = 2235
# Average deviation:  W =  134 H =  120
# RUNTIME: missing absolute size (460x)
# 	letters/ii001: xywh.page: 'todo' | 'full'
# 	letters/ii001: xywh.page: 'todo' | 'full'
# 	letters/ii002: xywh.page: 'todo' | 'full'
# 	letters/ii002: xywh.page: 'todo' | 'full'
# 	letters/ii002: xywh.page: 'todo' | 'full'
# 	letters/ii002: xywh.page: 'todo' | 'full'
# 	letters/ii003: xywh.page: 'todo' | 'full'
# 	letters/ii003: xywh.page: 'todo' | 'full'
# 	letters/ii004: xywh.page: 'todo' | 'full'
# 	letters/ii004: xywh.page: 'todo' | 'full'
# 	letters/ii004: xywh.page: 'todo' | 'full'
# 	letters/ii004: xywh.page: 'todo' | 'full'
# 	letters/ii005: xywh.page: 'todo' | 'full'
# 	letters/ii005: xywh.page: 'todo' | 'full'
# 	letters/ii005: xywh.page: 'todo' | 'full'
# 	letters/ii005: xywh.page: 'todo' | 'full'
# 	letters/ii006: xywh.page: 'todo' | 'full'
# 	letters/ii006: xywh.page: 'todo' | 'full'
# 	letters/ii006: xywh.page: 'todo' | 'full'
# 	letters/ii006: xywh.page: 'todo' | 'full'
# 	letters/ii007: xywh.page: 'todo' | 'full'
# 	letters/ii007: xywh.page: 'todo' | 'full'
# 	letters/ii008: xywh.page: 'z1r1' | 'full'
# 	letters/ii008: xywh.page: 'z1r2' | 'full'
# 	letters/ii008: xywh.page: 'z1r1' | 'full'
# 	letters/ii008: xywh.page: 'z1r2' | 'full'
# 	letters/ii009: xywh.page: 'todo' | 'full'
# 	letters/ii009: xywh.page: 'todo' | 'full'
# 	letters/ii009: xywh.page: 'todo' | 'full'
# 	letters/ii009: xywh.page: 'todo' | 'full'
# 	letters/ii010: xywh.page: 'z1r1' | 'full'
# 	letters/ii010: xywh.page: 'z1v2' | 'full'
# 	letters/ii010: xywh.page: 'z1v3' | 'full'
# 	letters/ii010: xywh.page: 'z1r4' | 'full'
# 	letters/ii010: xywh.page: 'z1r1' | 'full'
# 	letters/ii010: xywh.page: 'z1v2' | 'full'
# 	letters/ii010: xywh.page: 'z1v3' | 'full'
# 	letters/ii010: xywh.page: 'z1r4' | 'full'
# 	letters/ii011: xywh.page: 'todo' | 'full'
# 	letters/ii011: xywh.page: 'todo' | 'full'
# 	letters/ii011: xywh.page: 'todo' | 'full'
# 	letters/ii011: xywh.page: 'todo' | 'full'
# 	letters/ii012: xywh.page: 'z1r1' | 'full'
# 	letters/ii012: xywh.page: 'z1r2' | 'full'
# 	letters/ii012: xywh.page: 'z1r1' | 'full'
# 	letters/ii012: xywh.page: 'z1r2' | 'full'
# 	letters/ii013: xywh.page: 'todo' | 'full'
# 	letters/ii013: xywh.page: 'todo' | 'full'
# 	letters/ii014: xywh.page: 'todo' | 'full'
# 	letters/ii014: xywh.page: 'todo' | 'full'
# 	letters/ii014: xywh.page: 'todo' | 'full'
# 	letters/ii014: xywh.page: 'todo' | 'full'
# 	letters/ii015: xywh.page: 'todo' | 'full'
# 	letters/ii015: xywh.page: 'todo' | 'full'
# 	letters/ii015: xywh.page: 'todo' | 'full'
# 	letters/ii015: xywh.page: 'todo' | 'full'
# 	letters/ii016: xywh.page: 'todo' | 'full'
# 	letters/ii016: xywh.page: 'todo' | 'full'
# 	letters/ii017: xywh.page: 'z1r1' | 'full'
# 	letters/ii017: xywh.page: 'z1r2' | 'full'
# 	letters/ii017: xywh.page: 'z1r1' | 'full'
# 	letters/ii017: xywh.page: 'z1r2' | 'full'
# 	letters/ii018: xywh.page: 'z1r1' | 'full'
# 	letters/ii018: xywh.page: 'z1r2' | 'full'
# 	letters/ii018: xywh.page: 'z1r1' | 'full'
# 	letters/ii018: xywh.page: 'z1r2' | 'full'
# 	letters/ii019: xywh.page: 'todo' | 'full'
# 	letters/ii019: xywh.page: 'todo' | 'full'
# 	letters/ii020: xywh.page: 'todo' | 'full'
# 	letters/ii020: xywh.page: 'z1v2' | 'full'
# 	letters/ii020: xywh.page: 'z1v3' | 'full'
# 	letters/ii020: xywh.page: 'todo' | 'full'
# 	letters/ii020: xywh.page: 'z1v2' | 'full'
# 	letters/ii020: xywh.page: 'z1v3' | 'full'
# 	letters/ii021: xywh.page: 'todo' | 'full'
# 	letters/ii021: xywh.page: 'todo' | 'full'
# 	letters/ii022: xywh.page: 'z1r1' | 'full'
# 	letters/ii022: xywh.page: 'z1r2' | 'full'
# 	letters/ii022: xywh.page: 'z1r1' | 'full'
# 	letters/ii022: xywh.page: 'z1r2' | 'full'
# 	letters/ii023: xywh.page: 'todo' | 'full'
# 	letters/ii023: xywh.page: 'todo' | 'full'
# 	letters/ii024: xywh.page: 'todo' | 'full'
# 	letters/ii024: xywh.page: 'todo' | 'full'
# 	letters/ii025: xywh.page: 'todo' | 'full'
# 	letters/ii025: xywh.page: 'todo' | 'full'
# 	letters/ii026: xywh.page: 'todo' | 'full'
# 	letters/ii026: xywh.page: 'todo' | 'full'
# 	letters/ii027: xywh.page: 'todo' | 'full'
# 	letters/ii027: xywh.page: 'todo' | 'full'
# 	letters/ii028: xywh.page: 'todo' | 'full'
# 	letters/ii028: xywh.page: 'todo' | 'full'
# 	letters/ii028: xywh.page: 'todo' | 'full'
# 	letters/ii028: xywh.page: 'todo' | 'full'
# 	letters/ii029: xywh.page: 'z1r1' | 'full'
# 	letters/ii029: xywh.page: 'z1r2' | 'full'
# 	letters/ii029: xywh.page: 'z1v3' | 'full'
# 	letters/ii029: xywh.page: 'z1v4' | 'full'
# 	letters/ii029: xywh.page: 'z1r1' | 'full'
# 	letters/ii029: xywh.page: 'z1r2' | 'full'
# 	letters/ii029: xywh.page: 'z1v3' | 'full'
# 	letters/ii029: xywh.page: 'z1v4' | 'full'
# 	letters/ii030: xywh.page: 'z1r1' | 'full'
# 	letters/ii030: xywh.page: 'z1r2' | 'full'
# 	letters/ii030: xywh.page: 'z1r1' | 'full'
# 	letters/ii030: xywh.page: 'z1r2' | 'full'
# 	letters/ii031: xywh.page: 'todo' | 'full'
# 	letters/ii031: xywh.page: 'todo' | 'full'
# 	letters/ii032: xywh.page: 'todo' | 'full'
# 	letters/ii032: xywh.page: 'todo' | 'full'
# 	letters/ii032: xywh.page: 'todo' | 'full'
# 	letters/ii032: xywh.page: 'todo' | 'full'
# 	letters/ii033: xywh.page: 'todo' | 'full'
# 	letters/ii033: xywh.page: 'todo' | 'full'
# 	letters/ii033: xywh.page: 'todo' | 'full'
# 	letters/ii033: xywh.page: 'todo' | 'full'
# 	letters/ii034: xywh.page: 'todo' | 'full'
# 	letters/ii034: xywh.page: 'todo' | 'full'
# 	letters/ii034: xywh.page: 'todo' | 'full'
# 	letters/ii034: xywh.page: 'todo' | 'full'
# 	letters/ii035: xywh.page: 'z1r1' | 'full'
# 	letters/ii035: xywh.page: 'z1v2' | 'full'
# 	letters/ii035: xywh.page: 'z1v3' | 'full'
# 	letters/ii035: xywh.page: 'z1r4' | 'full'
# 	letters/ii035: xywh.page: 'z1r1' | 'full'
# 	letters/ii035: xywh.page: 'z1v2' | 'full'
# 	letters/ii035: xywh.page: 'z1v3' | 'full'
# 	letters/ii035: xywh.page: 'z1r4' | 'full'
# 	letters/ii036: xywh.page: 'z1r1' | 'full'
# 	letters/ii036: xywh.page: 'z1r2' | 'full'
# 	letters/ii036: xywh.page: 'z1r1' | 'full'
# 	letters/ii036: xywh.page: 'z1r2' | 'full'
# 	letters/ii037: xywh.page: 'todo' | 'full'
# 	letters/ii037: xywh.page: 'todo' | 'full'
# 	letters/ii038: xywh.page: 'todo' | 'full'
# 	letters/ii038: xywh.page: 'todo' | 'full'
# 	letters/ii038: xywh.page: 'todo' | 'full'
# 	letters/ii038: xywh.page: 'todo' | 'full'
# 	letters/ii039: xywh.page: 'todo' | 'full'
# 	letters/ii039: xywh.page: 'todo' | 'full'
# 	letters/ii039: xywh.page: 'todo' | 'full'
# 	letters/ii039: xywh.page: 'todo' | 'full'
# 	letters/ii040: xywh.page: 'z1r1' | 'full'
# 	letters/ii040: xywh.page: 'z1r2' | 'full'
# 	letters/ii040: xywh.page: 'z1r1' | 'full'
# 	letters/ii040: xywh.page: 'z1r2' | 'full'
# 	letters/ii041: xywh.page: 'todo' | 'full'
# 	letters/ii041: xywh.page: 'z1v2' | 'full'
# 	letters/ii041: xywh.page: 'z1v3' | 'full'
# 	letters/ii041: xywh.page: 'todo' | 'full'
# 	letters/ii041: xywh.page: 'z1v2' | 'full'
# 	letters/ii041: xywh.page: 'z1v3' | 'full'
# 	letters/ii042: xywh.page: 'z1r1' | 'full'
# 	letters/ii042: xywh.page: 'z1r2' | 'full'
# 	letters/ii042: xywh.page: 'z1r1' | 'full'
# 	letters/ii042: xywh.page: 'z1r2' | 'full'
# 	letters/ii043: xywh.page: 'todo' | 'full'
# 	letters/ii043: xywh.page: 'todo' | 'full'
# 	letters/ii044: xywh.page: 'todo' | 'full'
# 	letters/ii044: xywh.page: 'todo' | 'full'
# 	letters/ii045: xywh.page: 'todo' | 'full'
# 	letters/ii045: xywh.page: 'todo' | 'full'
# 	letters/ii045: xywh.page: 'todo' | 'full'
# 	letters/ii045: xywh.page: 'todo' | 'full'
# 	letters/ii046: xywh.page: 'todo' | 'full'
# 	letters/ii046: xywh.page: 'z1v2' | 'full'
# 	letters/ii046: xywh.page: 'z1v3' | 'full'
# 	letters/ii046: xywh.page: 'todo' | 'full'
# 	letters/ii046: xywh.page: 'z1v2' | 'full'
# 	letters/ii046: xywh.page: 'z1v3' | 'full'
# 	letters/ii047: xywh.page: 'todo' | 'full'
# 	letters/ii047: xywh.page: 'todo' | 'full'
# 	letters/ii048: xywh.page: 'todo' | 'full'
# 	letters/ii048: xywh.page: 'z1v2' | 'full'
# 	letters/ii048: xywh.page: 'z1v3' | 'full'
# 	letters/ii048: xywh.page: 'todo' | 'full'
# 	letters/ii048: xywh.page: 'z1v2' | 'full'
# 	letters/ii048: xywh.page: 'z1v3' | 'full'
# 	letters/ii049: xywh.page: 'todo' | 'full'
# 	letters/ii049: xywh.page: 'todo' | 'full'
# 	letters/ii050: xywh.page: 'todo' | 'full'
# 	letters/ii050: xywh.page: 'todo' | 'full'
# 	letters/ii051: xywh.page: 'todo' | 'full'
# 	letters/ii051: xywh.page: 'todo' | 'full'
# 	letters/ii052: xywh.page: 'todo' | 'full'
# 	letters/ii052: xywh.page: 'todo' | 'full'
# 	letters/ii052: xywh.page: 'todo' | 'full'
# 	letters/ii052: xywh.page: 'todo' | 'full'
# 	letters/ii053: xywh.page: 'todo' | 'full'
# 	letters/ii053: xywh.page: 'todo' | 'full'
# 	letters/ii054: xywh.page: 'todo' | 'full'
# 	letters/ii054: xywh.page: 'todo' | 'full'
# 	letters/ii055: xywh.page: 'todo' | 'full'
# 	letters/ii055: xywh.page: 'todo' | 'full'
# 	letters/ii056: xywh.page: 'todo' | 'full'
# 	letters/ii056: xywh.page: 'todo' | 'full'
# 	letters/ii056: xywh.page: 'todo' | 'full'
# 	letters/ii056: xywh.page: 'todo' | 'full'
# 	letters/ii057: xywh.page: 'z1r1' | 'full'
# 	letters/ii057: xywh.page: 'z1r2' | 'full'
# 	letters/ii057: xywh.page: 'todo' | 'full'
# 	letters/ii057: xywh.page: 'z1r1' | 'full'
# 	letters/ii057: xywh.page: 'z1r2' | 'full'
# 	letters/ii057: xywh.page: 'todo' | 'full'
# 	letters/ii058: xywh.page: 'todo' | 'full'
# 	letters/ii058: xywh.page: 'z1v2' | 'full'
# 	letters/ii058: xywh.page: 'z1v3' | 'full'
# 	letters/ii058: xywh.page: 'todo' | 'full'
# 	letters/ii058: xywh.page: 'todo' | 'full'
# 	letters/ii058: xywh.page: 'z1v2' | 'full'
# 	letters/ii058: xywh.page: 'z1v3' | 'full'
# 	letters/ii058: xywh.page: 'todo' | 'full'
# 	letters/ii059: xywh.page: 'todo' | 'full'
# 	letters/ii059: xywh.page: 'todo' | 'full'
# 	letters/ii059: xywh.page: 'todo' | 'full'
# 	letters/ii059: xywh.page: 'todo' | 'full'
# 	letters/ii059: xywh.page: 'todo' | 'full'
# 	letters/ii059: xywh.page: 'todo' | 'full'
# 	letters/ii060: xywh.page: 'todo' | 'full'
# 	letters/ii060: xywh.page: 'z1v2' | 'full'
# 	letters/ii060: xywh.page: 'z1v3' | 'full'
# 	letters/ii060: xywh.page: 'todo' | 'full'
# 	letters/ii060: xywh.page: 'z1v2' | 'full'
# 	letters/ii060: xywh.page: 'z1v3' | 'full'
# 	letters/ii061: xywh.page: 'todo' | 'full'
# 	letters/ii061: xywh.page: 'z1v2' | 'full'
# 	letters/ii061: xywh.page: 'z1v3' | 'full'
# 	letters/ii061: xywh.page: 'todo' | 'full'
# 	letters/ii061: xywh.page: 'todo' | 'full'
# 	letters/ii061: xywh.page: 'z1v2' | 'full'
# 	letters/ii061: xywh.page: 'z1v3' | 'full'
# 	letters/ii061: xywh.page: 'todo' | 'full'
# 	letters/ii062: xywh.page: 'todo' | 'full'
# 	letters/ii062: xywh.page: 'z1v2' | 'full'
# 	letters/ii062: xywh.page: 'z1v3' | 'full'
# 	letters/ii062: xywh.page: 'todo' | 'full'
# 	letters/ii062: xywh.page: 'todo' | 'full'
# 	letters/ii062: xywh.page: 'z1v2' | 'full'
# 	letters/ii062: xywh.page: 'z1v3' | 'full'
# 	letters/ii062: xywh.page: 'todo' | 'full'
# 	letters/ii063: xywh.page: 'todo' | 'full'
# 	letters/ii063: xywh.page: 'todo' | 'full'
# 	letters/ii063: xywh.page: 'todo' | 'full'
# 	letters/ii063: xywh.page: 'todo' | 'full'
# 	letters/ii064: xywh.page: 'todo' | 'full'
# 	letters/ii064: xywh.page: 'todo' | 'full'
# 	letters/ii064: xywh.page: 'todo' | 'full'
# 	letters/ii064: xywh.page: 'todo' | 'full'
# 	letters/ii065: xywh.page: 'todo' | 'full'
# 	letters/ii065: xywh.page: 'todo' | 'full'
# 	letters/ii066: xywh.page: 'todo' | 'full'
# 	letters/ii066: xywh.page: 'todo' | 'full'
# 	letters/ii066: xywh.page: 'todo' | 'full'
# 	letters/ii066: xywh.page: 'todo' | 'full'
# 	letters/ii066: xywh.page: 'todo' | 'full'
# 	letters/ii066: xywh.page: 'todo' | 'full'
# 	letters/ii067: xywh.page: 'todo' | 'full'
# 	letters/ii067: xywh.page: 'todo' | 'full'
# 	letters/ii067: xywh.page: 'todo' | 'full'
# 	letters/ii067: xywh.page: 'todo' | 'full'
# 	letters/ii067: xywh.page: 'todo' | 'full'
# 	letters/ii067: xywh.page: 'todo' | 'full'
# 	letters/ii068: xywh.page: 'todo' | 'full'
# 	letters/ii068: xywh.page: 'todo' | 'full'
# 	letters/ii068: xywh.page: 'todo' | 'full'
# 	letters/ii068: xywh.page: 'todo' | 'full'
# 	letters/ii069: xywh.page: 'todo' | 'full'
# 	letters/ii069: xywh.page: 'z1v2' | 'full'
# 	letters/ii069: xywh.page: 'z1v3' | 'full'
# 	letters/ii069: xywh.page: 'todo' | 'full'
# 	letters/ii069: xywh.page: 'todo' | 'full'
# 	letters/ii069: xywh.page: 'z1v2' | 'full'
# 	letters/ii069: xywh.page: 'z1v3' | 'full'
# 	letters/ii069: xywh.page: 'todo' | 'full'
# 	letters/ii070: xywh.page: 'todo' | 'full'
# 	letters/ii070: xywh.page: 'todo' | 'full'
# 	letters/ii070: xywh.page: 'todo' | 'full'
# 	letters/ii070: xywh.page: 'todo' | 'full'
# 	letters/ii071: xywh.page: 'todo' | 'full'
# 	letters/ii071: xywh.page: 'todo' | 'full'
# 	letters/ii071: xywh.page: 'todo' | 'full'
# 	letters/ii071: xywh.page: 'todo' | 'full'
# 	letters/ii072: xywh.page: 'todo' | 'full'
# 	letters/ii072: xywh.page: 'todo' | 'full'
# 	letters/ii072: xywh.page: 'todo' | 'full'
# 	letters/ii072: xywh.page: 'todo' | 'full'
# 	letters/ii073: xywh.page: 'todo' | 'full'
# 	letters/ii073: xywh.page: 'todo' | 'full'
# 	letters/ii073: xywh.page: 'todo' | 'full'
# 	letters/ii073: xywh.page: 'todo' | 'full'
# 	letters/ii074: xywh.page: 'todo' | 'full'
# 	letters/ii074: xywh.page: 'todo' | 'full'
# 	letters/ii074: xywh.page: 'todo' | 'full'
# 	letters/ii074: xywh.page: 'todo' | 'full'
# 	letters/ii075: xywh.page: 'todo' | 'full'
# 	letters/ii075: xywh.page: 'todo' | 'full'
# 	letters/ii075: xywh.page: 'todo' | 'full'
# 	letters/ii075: xywh.page: 'todo' | 'full'
# 	letters/ii076: xywh.page: 'todo' | 'full'
# 	letters/ii076: xywh.page: 'z1v2' | 'full'
# 	letters/ii076: xywh.page: 'z1v3' | 'full'
# 	letters/ii076: xywh.page: 'todo' | 'full'
# 	letters/ii076: xywh.page: 'todo' | 'full'
# 	letters/ii076: xywh.page: 'z1v2' | 'full'
# 	letters/ii076: xywh.page: 'z1v3' | 'full'
# 	letters/ii076: xywh.page: 'todo' | 'full'
# 	letters/ii077: xywh.page: 'todo' | 'full'
# 	letters/ii077: xywh.page: 'todo' | 'full'
# 	letters/ii077: xywh.page: 'todo' | 'full'
# 	letters/ii077: xywh.page: 'todo' | 'full'
# 	letters/ii078: xywh.page: 'todo' | 'full'
# 	letters/ii078: xywh.page: 'todo' | 'full'
# 	letters/ii078: xywh.page: 'todo' | 'full'
# 	letters/ii078: xywh.page: 'todo' | 'full'
# 	letters/ii078: xywh.page: 'todo' | 'full'
# 	letters/ii078: xywh.page: 'todo' | 'full'
# 	letters/ii079: xywh.page: 'todo' | 'full'
# 	letters/ii079: xywh.page: 'z1v2' | 'full'
# 	letters/ii079: xywh.page: 'z1v3' | 'full'
# 	letters/ii079: xywh.page: 'todo' | 'full'
# 	letters/ii079: xywh.page: 'todo' | 'full'
# 	letters/ii079: xywh.page: 'z1v2' | 'full'
# 	letters/ii079: xywh.page: 'z1v3' | 'full'
# 	letters/ii079: xywh.page: 'todo' | 'full'
# 	letters/ii080: xywh.page: 'todo' | 'full'
# 	letters/ii080: xywh.page: 'todo' | 'full'
# 	letters/ii080: xywh.page: 'todo' | 'full'
# 	letters/ii080: xywh.page: 'todo' | 'full'
# 	letters/ii080: xywh.page: 'todo' | 'full'
# 	letters/ii080: xywh.page: 'todo' | 'full'
# 	letters/ii081: xywh.page: 'todo' | 'full'
# 	letters/ii081: xywh.page: 'todo' | 'full'
# 	letters/ii081: xywh.page: 'todo' | 'full'
# 	letters/ii081: xywh.page: 'todo' | 'full'
# 	letters/ii081: xywh.page: 'todo' | 'full'
# 	letters/ii081: xywh.page: 'todo' | 'full'
# 	letters/ii082: xywh.page: 'todo' | 'full'
# 	letters/ii082: xywh.page: 'z1v2' | 'full'
# 	letters/ii082: xywh.page: 'z1v3' | 'full'
# 	letters/ii082: xywh.page: 'todo' | 'full'
# 	letters/ii082: xywh.page: 'todo' | 'full'
# 	letters/ii082: xywh.page: 'z1v2' | 'full'
# 	letters/ii082: xywh.page: 'z1v3' | 'full'
# 	letters/ii082: xywh.page: 'todo' | 'full'
# 	letters/ii083: xywh.page: 'todo' | 'full'
# 	letters/ii083: xywh.page: 'todo' | 'full'
# 	letters/ii083: xywh.page: 'todo' | 'full'
# 	letters/ii083: xywh.page: 'todo' | 'full'
# 	letters/ii083: xywh.page: 'todo' | 'full'
# 	letters/ii083: xywh.page: 'todo' | 'full'
# 	letters/ii084: xywh.page: 'todo' | 'full'
# 	letters/ii084: xywh.page: 'todo' | 'full'
# 	letters/ii084: xywh.page: 'todo' | 'full'
# 	letters/ii084: xywh.page: 'todo' | 'full'
# 	letters/ii085: xywh.page: 'todo' | 'full'
# 	letters/ii085: xywh.page: 'todo' | 'full'
# 	letters/ii085: xywh.page: 'todo' | 'full'
# 	letters/ii085: xywh.page: 'todo' | 'full'
# 	letters/ii085: xywh.page: 'todo' | 'full'
# 	letters/ii085: xywh.page: 'todo' | 'full'
# 	letters/ii086: xywh.page: 'todo' | 'full'
# 	letters/ii086: xywh.page: 'todo' | 'full'
# 	letters/ii086: xywh.page: 'todo' | 'full'
# 	letters/ii086: xywh.page: 'todo' | 'full'
# 	letters/ii087: xywh.page: 'todo' | 'full'
# 	letters/ii087: xywh.page: 'todo' | 'full'
# 	letters/ii087: xywh.page: 'todo' | 'full'
# 	letters/ii087: xywh.page: 'todo' | 'full'
# 	letters/ii088: xywh.page: 'todo' | 'full'
# 	letters/ii088: xywh.page: 'todo' | 'full'
# 	letters/ii088: xywh.page: 'todo' | 'full'
# 	letters/ii088: xywh.page: 'todo' | 'full'
# 	letters/ii088: xywh.page: 'todo' | 'full'
# 	letters/ii088: xywh.page: 'todo' | 'full'
# 	letters/ii089: xywh.page: 'todo' | 'full'
# 	letters/ii089: xywh.page: 'todo' | 'full'
# 	letters/ii089: xywh.page: 'todo' | 'full'
# 	letters/ii089: xywh.page: 'todo' | 'full'
# 	letters/ii090: xywh.page: 'todo' | 'full'
# 	letters/ii090: xywh.page: 'todo' | 'full'
# 	letters/ii090: xywh.page: 'todo' | 'full'
# 	letters/ii090: xywh.page: 'todo' | 'full'
# 	letters/ii091: xywh.page: 'todo' | 'full'
# 	letters/ii091: xywh.page: 'todo' | 'full'
# 	letters/ii091: xywh.page: 'todo' | 'full'
# 	letters/ii091: xywh.page: 'todo' | 'full'
# 	letters/ii092: xywh.page: 'z1r1' | 'full'
# 	letters/ii092: xywh.page: 'todo' | 'full'
# 	letters/ii092: xywh.page: 'z1r3' | 'full'
# 	letters/ii092: xywh.page: 'z1r1' | 'full'
# 	letters/ii092: xywh.page: 'todo' | 'full'
# 	letters/ii092: xywh.page: 'z1r3' | 'full'
# 	letters/ii093: xywh.page: 'todo' | 'full'
# 	letters/ii093: xywh.page: 'z1v2' | 'full'
# 	letters/ii093: xywh.page: 'z1v3' | 'full'
# 	letters/ii093: xywh.page: 'todo' | 'full'
# 	letters/ii093: xywh.page: 'z1v2' | 'full'
# 	letters/ii093: xywh.page: 'z1v3' | 'full'
# 	letters/ii094: xywh.page: 'z1r1' | 'full'
# 	letters/ii094: xywh.page: 'z1v2' | 'full'
# 	letters/ii094: xywh.page: 'z1v3' | 'full'
# 	letters/ii094: xywh.page: 'z1r4' | 'full'
# 	letters/ii094: xywh.page: 'z1r1' | 'full'
# 	letters/ii094: xywh.page: 'z1v2' | 'full'
# 	letters/ii094: xywh.page: 'z1v3' | 'full'
# 	letters/ii094: xywh.page: 'z1r4' | 'full'
# 	letters/ii095: xywh.page: 'todo' | 'full'
# 	letters/ii095: xywh.page: 'todo' | 'full'
# 	letters/ii095: xywh.page: 'todo' | 'full'
# 	letters/ii095: xywh.page: 'todo' | 'full'
# 	letters/ii096: xywh.page: 'z1r1' | 'full'
# 	letters/ii096: xywh.page: 'z1v2' | 'full'
# 	letters/ii096: xywh.page: 'z1v3' | 'full'
# 	letters/ii096: xywh.page: 'z1r4' | 'full'
# 	letters/ii096: xywh.page: 'z1r1' | 'full'
# 	letters/ii096: xywh.page: 'z1v2' | 'full'
# 	letters/ii096: xywh.page: 'z1v3' | 'full'
# 	letters/ii096: xywh.page: 'z1r4' | 'full'
# 	letters/ii097: xywh.page: 'todo' | 'full'
# 	letters/ii097: xywh.page: 'todo' | 'full'
# 	letters/ii097: xywh.page: 'todo' | 'full'
# 	letters/ii097: xywh.page: 'todo' | 'full'
# 	letters/ii098: xywh.page: 'z1r1' | 'full'
# 	letters/ii098: xywh.page: 'z1v2' | 'full'
# 	letters/ii098: xywh.page: 'z1v3' | 'full'
# 	letters/ii098: xywh.page: 'z1r4' | 'full'
# 	letters/ii098: xywh.page: 'z1r1' | 'full'
# 	letters/ii098: xywh.page: 'z1v2' | 'full'
# 	letters/ii098: xywh.page: 'z1v3' | 'full'
# 	letters/ii098: xywh.page: 'z1r4' | 'full'
# 	letters/ii099: xywh.page: 'todo' | 'full'
# 	letters/ii099: xywh.page: 'z1v2' | 'full'
# 	letters/ii099: xywh.page: 'z1v3' | 'full'
# 	letters/ii099: xywh.page: 'todo' | 'full'
# 	letters/ii099: xywh.page: 'z1v2' | 'full'
# 	letters/ii099: xywh.page: 'z1v3' | 'full'
# 	letters/ii100: xywh.page: 'todo' | 'full'
# 	letters/ii100: xywh.page: 'todo' | 'full'
# 	letters/ii100: xywh.page: 'todo' | 'full'
# 	letters/ii100: xywh.page: 'todo' | 'full'
# 	letters/ii101: xywh.page: 'todo' | 'full'
# 	letters/ii101: xywh.page: 'todo' | 'full'
# 	letters/ii101: xywh.page: 'todo' | 'full'
# 	letters/ii101: xywh.page: 'todo' | 'full'
# 	letters/ii102: xywh.page: 'todo' | 'full'
# 	letters/ii102: xywh.page: 'todo' | 'full'
# 	letters/ii102: xywh.page: 'todo' | 'full'
# 	letters/ii102: xywh.page: 'todo' | 'full'
# 	letters/ii103: xywh.page: 'todo' | 'full'
# 	letters/ii103: xywh.page: 'todo' | 'full'
# 	letters/ii103: xywh.page: 'todo' | 'full'
# 	letters/ii103: xywh.page: 'todo' | 'full'
# 	letters/ii103: xywh.page: 'todo' | 'full'
# 	letters/ii103: xywh.page: 'todo' | 'full'
# 	letters/ii80: xywh.page: 'z1r1' | 'full'
# 	letters/ii80: xywh.page: 'z1v2' | 'full'
# 	letters/ii80: xywh.page: 'z2r3' | 'full'
# 	letters/ii80: xywh.page: 'z1r1' | 'full'
# 	letters/ii80: xywh.page: 'z1v2' | 'full'
# 	letters/ii80: xywh.page: 'z2r3' | 'full'
# WARNING: targets across tier0 items, 3x
#               folder [   0:     0] - [   3:   569]
#               folder [   4:     0] - [ 107:   686]
#               folder [ 108:     0] - [ 111:  1054]
# 	Writing WATM ...
# Writing development data to ~/github/HuygensING/israels/watm/0.0.1/dev
# Text file    0:    19175 segments to ~/github/HuygensING/israels/watm/0.0.1/dev/text-0.tsv
# Text file    1:     2685 segments to ~/github/HuygensING/israels/watm/0.0.1/dev/text-1.tsv
# Text file    2:      478 segments to ~/github/HuygensING/israels/watm/0.0.1/dev/text-2.tsv
# Text file    3:      571 segments to ~/github/HuygensING/israels/watm/0.0.1/dev/text-3.tsv
# Text file    4:      632 segments to ~/github/HuygensING/israels/watm/0.0.1/dev/text-4.tsv
#
# Text files all:   120564 segments to 112 files
# Anno file    1:   163923 annotations written to ~/github/HuygensING/israels/watm/0.0.1/dev/anno-1.tsv
# Inherited annotations: 0
# Anno files all:   163923 annotations to 1 file
# Slot mapping written to ~/github/HuygensING/israels/watm/0.0.1/dev/pos2node.tsv
# Node mapping written to ~/github/HuygensING/israels/watm/0.0.1/dev/anno2node.tsv

# %% [markdown]
# # Step 7 Test the WATM against the TF

# %%
WA.error = False
WA.testAll()
# Out:
# 	Testing WATM ...
# Testing the text ...
# 	TF: 120564
# 	WA: 120564
# OK - whether the amounts of tokens agree
# 	TF: Letters from Isaac I ... ls  Richard Wagner
# 	WA: Letters from Isaac I ... ls  Richard Wagner
# OK - whether the text is the same
# Testing the elements ...
# 	TF:  17049
# 	WA:  17049
# OK - whether the amounts of elements and nodes agree
# Testing the processing instructions ...
# 	TF:      0
# 	WA:      0
# OK - whether the amounts of processing instructions agree
# Testing the element/pi annotations ...
# 	137613 element/pi annotations
# 	Element      :  17049 x
# 	Pi           :      0 x
# 	Other        : 144156 x
# 	Good name    :  17049 x
# 	Wrong name   :      0 x
# 	Good target  :  17049 x
# 	Wrong target :      0 x
# 	Unmapped     :      0 x
# OK - whether all element/pi annotations have good bodies
# OK - whether all element/pi annotations have good targets
# Testing the attributes ...
# 	46558 attribute values
# 	Good:     46558 x
# 	Wrong:        0 x
# OK - whether annotations are consistent with features
# 	WA attributes: 46558
# 	TF attributes: 46558
# OK - whether annotations are complete w.r.t. features
# Testing the format attributes ...
# 	31298 format values
# 	formatting attributes:
# 		 21458 x indent
# 		  3807 x italics
# 		  2393 x Illustratie_onderschrift
# 		   866 x Citaat
# 		   866 x _
# 		   838 x ingesprongen
# 		   489 x whiteline_above
# 		   240 x Endnote_Anchor
# 		   115 x blockletter
# 		    87 x Paragraafkop
# 		    85 x Subparagraafkop
# 		    28 x rechtsuitlijnend
# 		    26 x super
# 	Good:     31298 x
# 	Wrong:        0 x
# OK - whether format annotations are consistent with features
# 	WA format attributes: 31298
# 	TF format attributes: 31298
# OK - whether format annotations are complete w.r.t. features
# Testing the extra annotations ...
# 	0 extra feature values
# 	0 extra annotations
# OK - whether the extra annotations agree
# Testing the edges ...
# 	Found: 137613 nodes
# 	Found edge link_target with 1117 starting nodes
# 	Found edge parent with 15928 starting nodes
# 	Checking edge link_target
# 		same 1117 fromNodes
# 	OK - 1117 toNodes checked
# 	Checking edge parent
# 		same 15928 fromNodes
# 	OK - 15928 toNodes checked
# OK - whether all edges agree
# Overall outcome ...
# OK - whether all tests passed
